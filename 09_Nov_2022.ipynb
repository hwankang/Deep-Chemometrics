# %% [markdown]
# <a href="https://colab.research.google.com/github/hwankang/Deep-Chemometrics/blob/master/09_Nov_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series 객체

# %%
s=pd.Series([0,0.25,8])

# %%
s.values
# Out:
# array([0.  , 0.25, 8.  ])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s[1]
# Out:
# 0.25

# %%
s[1:3]
# Out:
# 1    0.25
# 2    8.00
# dtype: float64

# %%
s=pd.Series([0, 0.25, 0.5, 0.75,1.0],
            index=['a','b','c','d','e'])
s
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %%
s['e']
# Out:
# 1.0

# %%
s[['c','d','e']]
# Out:
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %%
'b'in s
# Out:
# True

# %%
s=pd.Series([0,0.25,0.5,0.75],
            index=[2,4,6,7])
s
# Out:
# 2    0.00
# 4    0.25
# 6    0.50
# 7    0.75
# dtype: float64

# %%
s[4]
# Out:
# 0.25

# %%
s[2:]
# Out:
# 6    0.50
# 7    0.75
# dtype: float64

# %%
s.unique()
# Out:
# array([0.  , 0.25, 0.5 , 0.75])

# %%
s.value_counts()
# Out:
# 0.00    1
# 0.25    1
# 0.50    1
# 0.75    1
# dtype: int64

# %%
s.isin([0.25,0.5])
# Out:
# 2    False
# 4     True
# 6     True
# 7    False
# dtype: bool

# %%
pop_tuple={'서울': 9700000,
           '인천': 3400000,
           '부산': 5600000,
           '대구': 2000000,
           '광주':1000000,
           '대전': 4500000}
population = pd.Series(pop_tuple)
population
# Out:
# 서울    9700000
# 인천    3400000
# 부산    5600000
# 대구    2000000
# 광주    1000000
# 대전    4500000
# dtype: int64

# %%
population['서울']
# Out:
# 9700000

# %%
population['서울':'부산']
# Out:
# 서울    9700000
# 인천    3400000
# 부산    5600000
# dtype: int64

# %% [markdown]
# #DataFrame 객체

# %%
pd.DataFrame([{'A':2,'B':4,'D':3}, {'A':4, 'B':5,'C':7}])
# Out:
#    A  B    D    C
# 0  2  4  3.0  NaN
# 1  4  5  NaN  7.0

# %%
pd.DataFrame(np.random.rand(5,5),
             columns=['A','B','C','D','E'],
             index=[1,2,3,4,5])
# Out:
#           A         B         C         D         E
# 1  0.870723  0.172516  0.735122  0.551678  0.519992
# 2  0.129603  0.541930  0.282066  0.893033  0.955368
# 3  0.952351  0.267987  0.463961  0.127025  0.576654
# 4  0.164655  0.167351  0.002446  0.304302  0.315319
# 5  0.681700  0.236938  0.642860  0.111148  0.228481

# %%
male_tuple={'서울': 970000,
           '인천': 340000,
           '부산': 560000,
           '대구': 200000,
           '광주':100000,
           '대전': 450000}
male=pd.Series(male_tuple)
male

# %%
female_tuple={'서울': 97000,
           '인천': 34000,
           '부산': 56000,
           '대구': 20000,
           '광주':10000,
           '대전': 45000}
female=pd.Series(female_tuple)
female
# Out:
# 서울    97000
# 인천    34000
# 부산    56000
# 대구    20000
# 광주    10000
# 대전    45000
# dtype: int64

# %%
korea_df=pd.DataFrame({'인구수':population,
                       '남자수':male,
                       '여자수':female})
korea_df
# Out:
#         인구수     남자수    여자수
# 서울  9700000  970000  97000
# 인천  3400000  340000  34000
# 부산  5600000  560000  56000
# 대구  2000000  200000  20000
# 광주  1000000  100000  10000
# 대전  4500000  450000  45000

# %%
korea_df.index
# Out:
# Index(['서울', '인천', '부산', '대구', '광주', '대전'], dtype='object')

# %%
korea_df.columns
# Out:
# Index(['인구수', '남자수', '여자수'], dtype='object')

# %%
korea_df['여자수']
# Out:
# 서울    97000
# 인천    34000
# 부산    56000
# 대구    20000
# 광주    10000
# 대전    45000
# Name: 여자수, dtype: int64

# %%
korea_df['서울':'인천']
# Out:
#         인구수     남자수    여자수
# 서울  9700000  970000  97000
# 인천  3400000  340000  34000

# %% [markdown]
# #index 객체

# %%
idx = pd.Index([2,4,6,8,10])
idx
# Out:
# Int64Index([2, 4, 6, 8, 10], dtype='int64')

# %%
idx[1]
# Out:
# 4

# %%
idx[1:2:2]
# Out:
# Int64Index([4], dtype='int64')

# %%
idx[-1::]
# Out:
# Int64Index([10], dtype='int64')

# %%
idx[::2]
# Out:
# Int64Index([2, 6, 10], dtype='int64')

# %%
print(idx)
print(idx.size)
print(idx.shape)
print(idx.ndim)
print(idx,type)
# Out:
# Int64Index([2, 4, 6, 8, 10], dtype='int64')
# 5
# (5,)
# 1
# Int64Index([2, 4, 6, 8, 10], dtype='int64') <class 'type'>

# %% [markdown]
# # index 연산

# %%
idx1 = pd.Index([1,2,4,6,8])
idx2 =pd.Index([2,4,5,6,7])
print(idx1.append(idx2))
print(idx1.difference(idx2))
print(idx1.intersection(idx2))
print(idx1&idx2)
print(idx1.union(idx2))
print(idx1 | idx2)
print(idx1.delete(0))
idx1.drop(2)
idx1 ^ idx2
# Out:
# Int64Index([1, 2, 4, 6, 8, 2, 4, 5, 6, 7], dtype='int64')
# Int64Index([1, 8], dtype='int64')
# Int64Index([2, 4, 6], dtype='int64')
# Int64Index([2, 4, 6], dtype='int64')
# Int64Index([1, 2, 4, 5, 6, 7, 8], dtype='int64')
# Int64Index([1, 2, 4, 5, 6, 7, 8], dtype='int64')
# Int64Index([2, 4, 6, 8], dtype='int64')
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Index.__xor__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__xor__.  Use index.symmetric_difference(other) instead
#   # This is added back by InteractiveShellApp.init_path()
# Int64Index([1, 5, 7, 8], dtype='int64')

# %% [markdown]
# #인덱싱

# %%
s=pd.Series([0,0.25,0.5,0.75,1.0],
            index=['a','b','c','d','e'])
s
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# dtype: float64

# %%
s['b']
# Out:
# 0.25

# %%
'b' in s
# Out:
# True

# %%
s.keys()
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
list(s.items())
# Out:
# [('a', 0.0), ('b', 0.25), ('c', 0.5), ('d', 0.75), ('e', 1.0)]

# %%
s['f']=1.25
s
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# e    1.00
# f    1.25
# dtype: float64

# %%
s['a':'d']
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# dtype: float64

# %%
s[0:4]
# Out:
# a    0.00
# b    0.25
# c    0.50
# d    0.75
# dtype: float64

# %%
s[(s>0.4)&(s<0.8)]
# Out:
# c    0.50
# d    0.75
# dtype: float64

# %%
s[['a','c','e']]
# Out:
# a    0.0
# c    0.5
# e    1.0
# dtype: float64

# %% [markdown]
# #Series 인덱싱

# %%
s = pd.Series(['a','b','c','d','e'],
              index=[1,3,5,7,9])
s[1]
s[2:4]
s
# Out:
# 1    a
# 3    b
# 5    c
# 7    d
# 9    e
# dtype: object

# %%
s
s.iloc[1]
# Out:
# 'b'

# %%
s.iloc[2:4]
# Out:
# 5    c
# 7    d
# dtype: object

# %%
s.reindex(range(10))
# Out:
# 0    NaN
# 1      a
# 2    NaN
# 3      b
# 4    NaN
# 5      c
# 6    NaN
# 7      d
# 8    NaN
# 9      e
# dtype: object

# %%
s.reindex(range(10),method='bfill')
# Out:
# 0    a
# 1    a
# 2    b
# 3    b
# 4    c
# 5    c
# 6    d
# 7    d
# 8    e
# 9    e
# dtype: object

# %% [markdown]
# # DataFrame 인덱싱

# %%
korea_df['남자수']
# Out:
# 서울    970000
# 인천    340000
# 부산    560000
# 대구    200000
# 광주    100000
# 대전    450000
# Name: 남자수, dtype: int64

# %%
korea_df.여자수
# Out:
# 서울    97000
# 인천    34000
# 부산    56000
# 대구    20000
# 광주    10000
# 대전    45000
# Name: 여자수, dtype: int64

# %%
korea_df['남녀비율']=(korea_df['남자수']*100/korea_df['여자수'])

# %%
korea_df.남녀비율
# Out:
# 서울    1000.0
# 인천    1000.0
# 부산    1000.0
# 대구    1000.0
# 광주    1000.0
# 대전    1000.0
# Name: 남녀비율, dtype: float64

# %%
korea_df.values
# Out:
# array([[9.7e+06, 9.7e+05, 9.7e+04, 1.0e+03],
#        [3.4e+06, 3.4e+05, 3.4e+04, 1.0e+03],
#        [5.6e+06, 5.6e+05, 5.6e+04, 1.0e+03],
#        [2.0e+06, 2.0e+05, 2.0e+04, 1.0e+03],
#        [1.0e+06, 1.0e+05, 1.0e+04, 1.0e+03],
#        [4.5e+06, 4.5e+05, 4.5e+04, 1.0e+03]])

# %%
korea_df.T
# Out:
#              서울         인천         부산         대구         광주         대전
# 인구수   9700000.0  3400000.0  5600000.0  2000000.0  1000000.0  4500000.0
# 남자수    970000.0   340000.0   560000.0   200000.0   100000.0   450000.0
# 여자수     97000.0    34000.0    56000.0    20000.0    10000.0    45000.0
# 남녀비율     1000.0     1000.0     1000.0     1000.0     1000.0     1000.0

# %%
korea_df.values[0]
# Out:
# array([9.7e+06, 9.7e+05, 9.7e+04, 1.0e+03])

# %%
korea_df['인구수']
# Out:
# 서울    9700000
# 인천    3400000
# 부산    5600000
# 대구    2000000
# 광주    1000000
# 대전    4500000
# Name: 인구수, dtype: int64

# %%
korea_df.loc[:'인천',:'남자수']
# Out:
#         인구수     남자수
# 서울  9700000  970000
# 인천  3400000  340000

# %%
korea_df.loc[(korea_df.여자수 >10000)]
# Out:
#         인구수     남자수    여자수    남녀비율
# 서울  9700000  970000  97000  1000.0
# 인천  3400000  340000  34000  1000.0
# 부산  5600000  560000  56000  1000.0
# 대구  2000000  200000  20000  1000.0
# 대전  4500000  450000  45000  1000.0

# %%
korea_df.loc[(korea_df.인구수 <2000000)]
# Out:
#         인구수     남자수    여자수    남녀비율
# 광주  1000000  100000  10000  1000.0

# %%
korea_df.loc()[korea_df.남녀비율>100]
# Out:
#         인구수     남자수    여자수    남녀비율
# 서울  9700000  970000  97000  1000.0
# 인천  3400000  340000  34000  1000.0
# 부산  5600000  560000  56000  1000.0
# 대구  2000000  200000  20000  1000.0
# 광주  1000000  100000  10000  1000.0
# 대전  4500000  450000  45000  1000.0

# %%
korea_df.loc[(korea_df.인구수> 20000) & (korea_df.남녀비율>100)]
# Out:
#         인구수     남자수    여자수    남녀비율
# 서울  9700000  970000  97000  1000.0
# 인천  3400000  340000  34000  1000.0
# 부산  5600000  560000  56000  1000.0
# 대구  2000000  200000  20000  1000.0
# 광주  1000000  100000  10000  1000.0
# 대전  4500000  450000  45000  1000.0

# %%
korea_df.iloc[:3,:2]
# Out:
#         인구수     남자수
# 서울  9700000  970000
# 인천  3400000  340000
# 부산  5600000  560000

# %% [markdown]
# # 다중 인덱싱 Series

# %%
idx_tuples=[('서울시',2010),('서울시',2020),
            ('부산시',2010),('부산시',2020),
            ('인천시',2010),('인천시',2020),
            ('대구시',2010),('대구시',2020),
            ('대전시',2010),('대전시',2020),
            ('광주시',2010),('광주시',2020)]
idx_tuples
# Out:
# [('서울시', 2010),
#  ('서울시', 2020),
#  ('부산시', 2010),
#  ('부산시', 2020),
#  ('인천시', 2010),
#  ('인천시', 2020),
#  ('대구시', 2010),
#  ('대구시', 2020),
#  ('대전시', 2010),
#  ('대전시', 2020),
#  ('광주시', 2010),
#  ('광주시', 2020)]

# %%
pop_tuples=[10312545, 9720846,
            2567910,3404423,
            2757296,2947217,
            2511676,2427954,
            1503664,1471040,
            1454636,1455048]
population= pd.Series(pop_tuples,index=idx_tuples)
population
# Out:
# (서울시, 2010)    10312545
# (서울시, 2020)     9720846
# (부산시, 2010)     2567910
# (부산시, 2020)     3404423
# (인천시, 2010)     2757296
# (인천시, 2020)     2947217
# (대구시, 2010)     2511676
# (대구시, 2020)     2427954
# (대전시, 2010)     1503664
# (대전시, 2020)     1471040
# (광주시, 2010)     1454636
# (광주시, 2020)     1455048
# dtype: int64

# %%
midx=pd.MultiIndex.from_tuples(idx_tuples)
midx
# Out:
# MultiIndex([('서울시', 2010),
#             ('서울시', 2020),
#             ('부산시', 2010),
#             ('부산시', 2020),
#             ('인천시', 2010),
#             ('인천시', 2020),
#             ('대구시', 2010),
#             ('대구시', 2020),
#             ('대전시', 2010),
#             ('대전시', 2020),
#             ('광주시', 2010),
#             ('광주시', 2020)],
#            )

# %%
population = population.reindex(midx)

# %%
population
# Out:
# 서울시  2010    10312545
#      2020     9720846
# 부산시  2010     2567910
#      2020     3404423
# 인천시  2010     2757296
#      2020     2947217
# 대구시  2010     2511676
#      2020     2427954
# 대전시  2010     1503664
#      2020     1471040
# 광주시  2010     1454636
#      2020     1455048
# dtype: int64

# %%
population[:,2010]
# Out:
# 서울시    10312545
# 부산시     2567910
# 인천시     2757296
# 대구시     2511676
# 대전시     1503664
# 광주시     1454636
# dtype: int64

# %%
population['대전시',:]
# Out:
# 2010    1503664
# 2020    1471040
# dtype: int64

# %%
korea_mdf=population.unstack()
korea_mdf
# Out:
#          2010     2020
# 광주시   1454636  1455048
# 대구시   2511676  2427954
# 대전시   1503664  1471040
# 부산시   2567910  3404423
# 서울시  10312545  9720846
# 인천시   2757296  2947217

# %%
korea_mdf.stack()
# Out:
# 광주시  2010     1454636
#      2020     1455048
# 대구시  2010     2511676
#      2020     2427954
# 대전시  2010     1503664
#      2020     1471040
# 부산시  2010     2567910
#      2020     3404423
# 서울시  2010    10312545
#      2020     9720846
# 인천시  2010     2757296
#      2020     2947217
# dtype: int64

# %%
male_tuples=[5111259,4732275,
            1773170,1668618,
            1390356,1476813,
            1255245,1198815,
            763648,734441,
            721780,720060]
male_tuples
# Out:
# [5111259,
#  4732275,
#  1773170,
#  1668618,
#  1390356,
#  1476813,
#  1255245,
#  1198815,
#  763648,
#  734441,
#  721780,
#  720060]

# %%
female_tuples=[5201286,4988571,
               1794740,1735805,
               1367940,1470404,
               1256431,1229139,
               750016,736599,
               732856,734988]
female_tuples
# Out:
# [5201286,
#  4988571,
#  1794740,
#  1735805,
#  1367940,
#  1470404,
#  1256431,
#  1229139,
#  750016,
#  736599,
#  732856,
#  734988]

# %%
korea_mdf=pd.DataFrame({'인구수':population,
                        '남자수':male_tuples,
                        '여자수':female_tuples})
korea_mdf
# Out:
#                인구수      남자수      여자수
# 서울시 2010  10312545  5111259  5201286
#     2020   9720846  4732275  4988571
# 부산시 2010   2567910  1773170  1794740
#     2020   3404423  1668618  1735805
# 인천시 2010   2757296  1390356  1367940
#     2020   2947217  1476813  1470404
# 대구시 2010   2511676  1255245  1256431
#     2020   2427954  1198815  1229139
# 대전시 2010   1503664   763648   750016
#     2020   1471040   734441   736599
# 광주시 2010   1454636   721780   732856
#     2020   1455048   720060   734988

# %%
ratio=korea_mdf['남자수']*100/korea_mdf['여자수']
ratio
# Out:
# 서울시  2010     98.269140
#      2020     94.862336
# 부산시  2010     98.798155
#      2020     96.129346
# 인천시  2010    101.638668
#      2020    100.435867
# 대구시  2010     99.905606
#      2020     97.532907
# 대전시  2010    101.817561
#      2020     99.707032
# 광주시  2010     98.488653
#      2020     97.968946
# dtype: float64

# %%
ratio.unstack()
# Out:
#            2010        2020
# 광주시   98.488653   97.968946
# 대구시   99.905606   97.532907
# 대전시  101.817561   99.707032
# 부산시   98.798155   96.129346
# 서울시   98.269140   94.862336
# 인천시  101.638668  100.435867

# %%
korea_mdf=pd.DataFrame({'인구수':population,
                        '남자수':male_tuples,
                        '여자수':female_tuples,
                       '남녀비율': ratio})
korea_mdf
# Out:
#                인구수      남자수      여자수        남녀비율
# 서울시 2010  10312545  5111259  5201286   98.269140
#     2020   9720846  4732275  4988571   94.862336
# 부산시 2010   2567910  1773170  1794740   98.798155
#     2020   3404423  1668618  1735805   96.129346
# 인천시 2010   2757296  1390356  1367940  101.638668
#     2020   2947217  1476813  1470404  100.435867
# 대구시 2010   2511676  1255245  1256431   99.905606
#     2020   2427954  1198815  1229139   97.532907
# 대전시 2010   1503664   763648   750016  101.817561
#     2020   1471040   734441   736599   99.707032
# 광주시 2010   1454636   721780   732856   98.488653
#     2020   1455048   720060   734988   97.968946

# %% [markdown]
# #다중 인덱스 생성

# %%
df=pd.DataFrame(np.random.rand(6,3),
                index=[['a','a','b','b','c','c'],[1,2,1,2,1,2]],
                columns=['c1','c2','c3'])
df
# Out:
#            c1        c2        c3
# a 1  0.257124  0.874462  0.642661
#   2  0.403006  0.270752  0.708868
# b 1  0.399470  0.934653  0.405511
#   2  0.323277  0.920788  0.505362
# c 1  0.619871  0.786482  0.340197
#   2  0.692319  0.725389  0.455196

# %%
pd.MultiIndex.from_arrays([['a','a','b','b','c','c'],[1,2,1,2,1,2]])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2)],
#            )

# %%
pd.MultiIndex.from_tuples([('a',1),('a',2),('b',1),('b',2),('c',1),('c',2)])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2)],
#            )

# %%
pd.MultiIndex.from_product([['a','b','c'],[1,2]])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2)],
#            )

# %%
pd.MultiIndex(levels=[['a','b','c'],[1,2]],
             codes=[[0,0,1,1,2,2],[0,1,0,1,0,1]])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2)],
#            )

# %%
population
# Out:
# 서울시  2010    10312545
#      2020     9720846
# 부산시  2010     2567910
#      2020     3404423
# 인천시  2010     2757296
#      2020     2947217
# 대구시  2010     2511676
#      2020     2427954
# 대전시  2010     1503664
#      2020     1471040
# 광주시  2010     1454636
#      2020     1455048
# dtype: int64

# %%
population.index.names=['행정구역','년도']
population
# Out:
# 행정구역  년도
# 서울시   2010    10312545
#       2020     9720846
# 부산시   2010     2567910
#       2020     3404423
# 인천시   2010     2757296
#       2020     2947217
# 대구시   2010     2511676
#       2020     2427954
# 대전시   2010     1503664
#       2020     1471040
# 광주시   2010     1454636
#       2020     1455048
# dtype: int64

# %%
idx=pd.MultiIndex.from_product([['a','b','c'],[1,2]],
                               names=['name1','name2'])
cols=pd.MultiIndex.from_product([['c1','c2','c3'],[1,2]],
                                names=['col_name1','col_name_2'])
data=np.round(np.random.randn(6,6),2)
mdf=pd.DataFrame(data,index=idx, columns=cols)
mdf
# Out:
# col_name1      c1          c2          c3
# col_name_2      1     2     1     2     1     2
# name1 name2
# a     1      0.52 -1.18 -0.51 -0.28 -0.31  0.85
#       2      0.06  1.01 -1.00  0.91  0.48  0.73
# b     1      1.67 -0.54  0.60 -0.12  1.58  0.34
#       2      0.65 -0.59  0.19 -0.37 -0.95  0.76
# c     1     -1.21 -1.11 -0.10 -0.07  0.00  1.03
#       2      0.40  2.18 -0.87  1.21  0.41  0.80

# %%
mdf['c2']
# Out:
# col_name_2      1     2
# name1 name2
# a     1     -0.51 -0.28
#       2     -1.00  0.91
# b     1      0.60 -0.12
#       2      0.19 -0.37
# c     1     -0.10 -0.07
#       2     -0.87  1.21

# %% [markdown]
# #인덱싱 및 슬라이딩

# %%
population['인천시', 2010]
# Out:
# 2757296

# %%
population[:,2010]
# Out:
# 행정구역
# 서울시    10312545
# 부산시     2567910
# 인천시     2757296
# 대구시     2511676
# 대전시     1503664
# 광주시     1454636
# dtype: int64

# %%
population[population>2000]
# Out:
# 행정구역  년도
# 서울시   2010    10312545
#       2020     9720846
# 부산시   2010     2567910
#       2020     3404423
# 인천시   2010     2757296
#       2020     2947217
# 대구시   2010     2511676
#       2020     2427954
# 대전시   2010     1503664
#       2020     1471040
# 광주시   2010     1454636
#       2020     1455048
# dtype: int64

# %%
population[['대구시','대전시']]
# Out:
# 행정구역  년도
# 대구시   2010    2511676
#       2020    2427954
# 대전시   2010    1503664
#       2020    1471040
# dtype: int64

# %%
mdf['c2',1]
# Out:
# name1  name2
# a      1       -0.51
#        2       -1.00
# b      1        0.60
#        2        0.19
# c      1       -0.10
#        2       -0.87
# Name: (c2, 1), dtype: float64

# %%
mdf.iloc[:3,:4]
# Out:
# col_name1      c1          c2
# col_name_2      1     2     1     2
# name1 name2
# a     1      0.52 -1.18 -0.51 -0.28
#       2      0.06  1.01 -1.00  0.91
# b     1      1.67 -0.54  0.60 -0.12

# %%
mdf.loc[:,('c2',1)]
# Out:
# name1  name2
# a      1       -0.51
#        2       -1.00
# b      1        0.60
#        2        0.19
# c      1       -0.10
#        2       -0.87
# Name: (c2, 1), dtype: float64

# %%
idx_slice=pd.IndexSlice
mdf.loc[idx_slice[:,2],idx_slice[:,2]]
# Out:
# col_name1      c1    c2    c3
# col_name_2      2     2     2
# name1 name2
# a     2      1.01  0.91  0.73
# b     2     -0.59 -0.37  0.76
# c     2      2.18  1.21  0.80

# %% [markdown]
# #다중 인텍싱 재정렬

# %%
mdf
# Out:
# col_name1      c1          c2          c3
# col_name_2      1     2     1     2     1     2
# name1 name2
# a     1      0.52 -1.18 -0.51 -0.28 -0.31  0.85
#       2      0.06  1.01 -1.00  0.91  0.48  0.73
# b     1      1.67 -0.54  0.60 -0.12  1.58  0.34
#       2      0.65 -0.59  0.19 -0.37 -0.95  0.76
# c     1     -1.21 -1.11 -0.10 -0.07  0.00  1.03
#       2      0.40  2.18 -0.87  1.21  0.41  0.80

# %%
idx
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2),
#             ('c', 1),
#             ('c', 2)],
#            names=['name1', 'name2'])

# %%
korea_df
# Out:
#         인구수     남자수    여자수    남녀비율
# 서울  9700000  970000  97000  1000.0
# 인천  3400000  340000  34000  1000.0
# 부산  5600000  560000  56000  1000.0
# 대구  2000000  200000  20000  1000.0
# 광주  1000000  100000  10000  1000.0
# 대전  4500000  450000  45000  1000.0

# %%
korea_mdf
# Out:
#                 인구수      남자수      여자수        남녀비율
# 행정구역 년도
# 서울시  2010  10312545  5111259  5201286   98.269140
#      2020   9720846  4732275  4988571   94.862336
# 부산시  2010   2567910  1773170  1794740   98.798155
#      2020   3404423  1668618  1735805   96.129346
# 인천시  2010   2757296  1390356  1367940  101.638668
#      2020   2947217  1476813  1470404  100.435867
# 대구시  2010   2511676  1255245  1256431   99.905606
#      2020   2427954  1198815  1229139   97.532907
# 대전시  2010   1503664   763648   750016  101.817561
#      2020   1471040   734441   736599   99.707032
# 광주시  2010   1454636   721780   732856   98.488653
#      2020   1455048   720060   734988   97.968946

# %%
korea_mdf=korea_mdf.sort_index()
korea_mdf
# Out:
#                 인구수      남자수      여자수        남녀비율
# 행정구역 년도
# 광주시  2010   1454636   721780   732856   98.488653
#      2020   1455048   720060   734988   97.968946
# 대구시  2010   2511676  1255245  1256431   99.905606
#      2020   2427954  1198815  1229139   97.532907
# 대전시  2010   1503664   763648   750016  101.817561
#      2020   1471040   734441   736599   99.707032
# 부산시  2010   2567910  1773170  1794740   98.798155
#      2020   3404423  1668618  1735805   96.129346
# 서울시  2010  10312545  5111259  5201286   98.269140
#      2020   9720846  4732275  4988571   94.862336
# 인천시  2010   2757296  1390356  1367940  101.638668
#      2020   2947217  1476813  1470404  100.435867

# %%
korea_mdf['서울시':'인천시']
# Out:
#                 인구수      남자수      여자수        남녀비율
# 행정구역 년도
# 서울시  2010  10312545  5111259  5201286   98.269140
#      2020   9720846  4732275  4988571   94.862336
# 인천시  2010   2757296  1390356  1367940  101.638668
#      2020   2947217  1476813  1470404  100.435867

# %%
korea_mdf.unstack(level=0)
# Out:
#           인구수                                                   남자수           \
# 행정구역      광주시      대구시      대전시      부산시       서울시      인천시     광주시      대구시
# 년도
# 2010  1454636  2511676  1503664  2567910  10312545  2757296  721780  1255245
# 2020  1455048  2427954  1471040  3404423   9720846  2947217  720060  1198815
#
#                        ...     여자수                                  남녀비율  \
# 행정구역     대전시      부산시  ...     대전시      부산시      서울시      인천시        광주시
# 년도                     ...
# 2010  763648  1773170  ...  750016  1794740  5201286  1367940  98.488653
# 2020  734441  1668618  ...  736599  1735805  4988571  1470404  97.968946
#
#
# 행정구역        대구시         대전시        부산시        서울시         인천시
# 년도
# 2010  99.905606  101.817561  98.798155  98.269140  101.638668
# 2020  97.532907   99.707032  96.129346  94.862336  100.435867
#
# [2 rows x 24 columns]

# %%
korea_mdf.unstack(level=1)
# Out:
#            인구수               남자수               여자수                 남녀비율  \
# 년도        2010     2020     2010     2020     2010     2020        2010
# 행정구역
# 광주시    1454636  1455048   721780   720060   732856   734988   98.488653
# 대구시    2511676  2427954  1255245  1198815  1256431  1229139   99.905606
# 대전시    1503664  1471040   763648   734441   750016   736599  101.817561
# 부산시    2567910  3404423  1773170  1668618  1794740  1735805   98.798155
# 서울시   10312545  9720846  5111259  4732275  5201286  4988571   98.269140
# 인천시    2757296  2947217  1390356  1476813  1367940  1470404  101.638668
#
#
# 년도          2020
# 행정구역
# 광주시    97.968946
# 대구시    97.532907
# 대전시    99.707032
# 부산시    96.129346
# 서울시    94.862336
# 인천시   100.435867

# %%
korea_mdf.stack()
# Out:
# 행정구역  년도
# 광주시   2010  인구수     1.454636e+06
#             남자수     7.217800e+05
#             여자수     7.328560e+05
#             남녀비율    9.848865e+01
#       2020  인구수     1.455048e+06
#             남자수     7.200600e+05
#             여자수     7.349880e+05
#             남녀비율    9.796895e+01
# 대구시   2010  인구수     2.511676e+06
#             남자수     1.255245e+06
#             여자수     1.256431e+06
#             남녀비율    9.990561e+01
#       2020  인구수     2.427954e+06
#             남자수     1.198815e+06
#             여자수     1.229139e+06
#             남녀비율    9.753291e+01
# 대전시   2010  인구수     1.503664e+06
#             남자수     7.636480e+05
#             여자수     7.500160e+05
#             남녀비율    1.018176e+02
#       2020  인구수     1.471040e+06
#             남자수     7.344410e+05
#             여자수     7.365990e+05
#             남녀비율    9.970703e+01
# 부산시   2010  인구수     2.567910e+06
#             남자수     1.773170e+06
#             여자수     1.794740e+06
#             남녀비율    9.879815e+01
#       2020  인구수     3.404423e+06
#             남자수     1.668618e+06
#             여자수     1.735805e+06
#             남녀비율    9.612935e+01
# 서울시   2010  인구수     1.031254e+07
#             남자수     5.111259e+06
#             여자수     5.201286e+06
#             남녀비율    9.826914e+01
#       2020  인구수     9.720846e+06
#             남자수     4.732275e+06
#             여자수     4.988571e+06
#             남녀비율    9.486234e+01
# 인천시   2010  인구수     2.757296e+06
#             남자수     1.390356e+06
#             여자수     1.367940e+06
#             남녀비율    1.016387e+02
#       2020  인구수     2.947217e+06
#             남자수     1.476813e+06
#             여자수     1.470404e+06
#             남녀비율    1.004359e+02
# dtype: float64

# %%
idx_flat=korea_mdf.reset_index(level=0)
idx_flat
# Out:
#      행정구역       인구수      남자수      여자수        남녀비율
# 년도
# 2010  광주시   1454636   721780   732856   98.488653
# 2020  광주시   1455048   720060   734988   97.968946
# 2010  대구시   2511676  1255245  1256431   99.905606
# 2020  대구시   2427954  1198815  1229139   97.532907
# 2010  대전시   1503664   763648   750016  101.817561
# 2020  대전시   1471040   734441   736599   99.707032
# 2010  부산시   2567910  1773170  1794740   98.798155
# 2020  부산시   3404423  1668618  1735805   96.129346
# 2010  서울시  10312545  5111259  5201286   98.269140
# 2020  서울시   9720846  4732275  4988571   94.862336
# 2010  인천시   2757296  1390356  1367940  101.638668
# 2020  인천시   2947217  1476813  1470404  100.435867

# %%
idx_flat=korea_mdf.reset_index(level=(0,1))
idx_flat
# Out:
#    행정구역    년도       인구수      남자수      여자수        남녀비율
# 0   광주시  2010   1454636   721780   732856   98.488653
# 1   광주시  2020   1455048   720060   734988   97.968946
# 2   대구시  2010   2511676  1255245  1256431   99.905606
# 3   대구시  2020   2427954  1198815  1229139   97.532907
# 4   대전시  2010   1503664   763648   750016  101.817561
# 5   대전시  2020   1471040   734441   736599   99.707032
# 6   부산시  2010   2567910  1773170  1794740   98.798155
# 7   부산시  2020   3404423  1668618  1735805   96.129346
# 8   서울시  2010  10312545  5111259  5201286   98.269140
# 9   서울시  2020   9720846  4732275  4988571   94.862336
# 10  인천시  2010   2757296  1390356  1367940  101.638668
# 11  인천시  2020   2947217  1476813  1470404  100.435867

# %%
idx_flat.set_index(['행정구역','년도'])
# Out:
#                 인구수      남자수      여자수        남녀비율
# 행정구역 년도
# 광주시  2010   1454636   721780   732856   98.488653
#      2020   1455048   720060   734988   97.968946
# 대구시  2010   2511676  1255245  1256431   99.905606
#      2020   2427954  1198815  1229139   97.532907
# 대전시  2010   1503664   763648   750016  101.817561
#      2020   1471040   734441   736599   99.707032
# 부산시  2010   2567910  1773170  1794740   98.798155
#      2020   3404423  1668618  1735805   96.129346
# 서울시  2010  10312545  5111259  5201286   98.269140
#      2020   9720846  4732275  4988571   94.862336
# 인천시  2010   2757296  1390356  1367940  101.638668
#      2020   2947217  1476813  1470404  100.435867

# %% [markdown]
# #데이터 연산

# %%
s=pd.Series(np.random.randint(0,10,5))
s
# Out:
# 0    7
# 1    7
# 2    8
# 3    2
# 4    4
# dtype: int64

# %%
df=pd.DataFrame(np.random.randint(0,10,(3,3)),
                columns=['A','B','C'])
df
# Out:
#    A  B  C
# 0  7  5  6
# 1  3  1  8
# 2  7  4  8

# %%
np.exp(s)
# Out:
# 0    1096.633158
# 1    1096.633158
# 2    2980.957987
# 3       7.389056
# 4      54.598150
# dtype: float64

# %%
np.cos(df*np.pi/4)
# Out:
#           A         B             C
# 0  0.707107 -0.707107 -1.836970e-16
# 1 -0.707107  0.707107  1.000000e+00
# 2  0.707107 -1.000000  1.000000e+00

# %%
s1=pd.Series([1,3,5,7,9],index=[0,1,2,3,4,])
s2=pd.Series([2,4,6,8,10],index=[1,2,3,4,5])
s1+s2
# Out:
# 0     NaN
# 1     5.0
# 2     9.0
# 3    13.0
# 4    17.0
# 5     NaN
# dtype: float64

# %%
s1.add(s2,fill_value=0)
# Out:
# 0     1.0
# 1     5.0
# 2     9.0
# 3    13.0
# 4    17.0
# 5    10.0
# dtype: float64

# %%
df1=pd.DataFrame(np.random.randint(0,20,(3,3)),
                    columns=list('ACD'))
df1
# Out:
#     A   C   D
# 0   0  19   1
# 1   8  15   1
# 2  11   4  18

# %%
df2=pd.DataFrame(np.random.randint(0,20,(5,5)),
                    columns=list('BAECD'))
df2
# Out:
#     B   A   E   C   D
# 0   4   9   9   5   9
# 1   7   9  11  14   4
# 2  14   4   4  10  13
# 3  12   8   4  18  13
# 4   0  15  10  14  14

# %%
df1+df2
# Out:
#       A   B     C     D   E
# 0   9.0 NaN  24.0  10.0 NaN
# 1  17.0 NaN  29.0   5.0 NaN
# 2  15.0 NaN  14.0  31.0 NaN
# 3   NaN NaN   NaN   NaN NaN
# 4   NaN NaN   NaN   NaN NaN

# %%
fvalue=df1.stack().mean()
df1.add(df2,fill_value=fvalue)
# Out:
#            A          B          C          D          E
# 0   9.000000  12.555556  24.000000  10.000000  17.555556
# 1  17.000000  15.555556  29.000000   5.000000  19.555556
# 2  15.000000  22.555556  14.000000  31.000000  12.555556
# 3  16.555556  20.555556  26.555556  21.555556  12.555556
# 4  23.555556   8.555556  22.555556  22.555556  18.555556

# %% [markdown]
# #연산자 범용 함수

# %%
a=np.random.randint(1,10,size=(3,3))
a
# Out:
# array([[8, 6, 9],
#        [6, 9, 9],
#        [9, 2, 4]])

# %%
a+a[0]
# Out:
# array([[16, 12, 18],
#        [14, 15, 18],
#        [17,  8, 13]])

# %%
df=pd.DataFrame(a,columns=list('ABC'))
df
# Out:
#    A  B  C
# 0  8  6  9
# 1  6  9  9
# 2  9  2  4

# %%
df+df.iloc[0]
# Out:
#     A   B   C
# 0  16  12  18
# 1  14  15  18
# 2  17   8  13

# %%
df.add(df.iloc[0])
# Out:
#     A   B   C
# 0  16  12  18
# 1  14  15  18
# 2  17   8  13

# %% [markdown]
# ## sub()/subtract()

# %%
a
# Out:
# array([[8, 6, 9],
#        [6, 9, 9],
#        [9, 2, 4]])

# %%
a+a[0]
# Out:
# array([[16, 12, 18],
#        [14, 15, 18],
#        [17,  8, 13]])

# %%
df.sub(df.iloc[0])
# Out:
#    A  B  C
# 0  0  0  0
# 1 -2  3  0
# 2  1 -4 -5

# %%
df.subtract(df['B'],axis=0)
# Out:
#    A  B  C
# 0  2  0  3
# 1 -3  0  0
# 2  7  0  2

# %% [markdown]
# ##mul()/multiply

# %%
df=pd.DataFrame(a,columns=list('ABC'))
df
# Out:
#    A  B  C
# 0  8  6  9
# 1  6  9  9
# 2  9  2  4

# %%
df.subtract(df['B'],axis=0)
# Out:
#    A  B  C
# 0  2  0  3
# 1 -3  0  0
# 2  7  0  2

# %%
df.mul(df.iloc[1])
# Out:
#     A   B   C
# 0  48  54  81
# 1  36  81  81
# 2  54  18  36

# %%
df.multiply(df.iloc[2])
# Out:
#     A   B   C
# 0  72  12  36
# 1  54  18  36
# 2  81   4  16

# %% [markdown]
# ##truediv()/div()/divide()/floordiv()

# %%
a
# Out:
# array([[8, 6, 9],
#        [6, 9, 9],
#        [9, 2, 4]])

# %%
df
# Out:
#    A  B  C
# 0  8  6  9
# 1  6  9  9
# 2  9  2  4

# %%
df/df.iloc[0]
# Out:
#        A         B         C
# 0  1.000  1.000000  1.000000
# 1  0.750  1.500000  1.000000
# 2  1.125  0.333333  0.444444

# %%
df.truediv(df.iloc[0])
# Out:
#        A         B         C
# 0  1.000  1.000000  1.000000
# 1  0.750  1.500000  1.000000
# 2  1.125  0.333333  0.444444

# %%
df.div(df.iloc[1])
# Out:
#           A         B         C
# 0  1.333333  0.666667  1.000000
# 1  1.000000  1.000000  1.000000
# 2  1.500000  0.222222  0.444444

# %%
df.divide(df.iloc[2])
# Out:
#           A    B     C
# 0  0.888889  3.0  2.25
# 1  0.666667  4.5  2.25
# 2  1.000000  1.0  1.00

# %%
a//a[0]
# Out:
# array([[1, 1, 1],
#        [0, 1, 1],
#        [1, 0, 0]])

# %%
df.floordiv(a[0])
# Out:
#    A  B  C
# 0  1  1  1
# 1  0  1  1
# 2  1  0  0

# %% [markdown]
# ##mod

# %%
a
# Out:
# array([[8, 6, 9],
#        [6, 9, 9],
#        [9, 2, 4]])

# %%
a%a[0]
# Out:
# array([[0, 0, 0],
#        [6, 3, 0],
#        [1, 2, 4]])

# %%
df
# Out:
#    A  B  C
# 0  8  6  9
# 1  6  9  9
# 2  9  2  4

# %%
df.mod(df.iloc[0])
# Out:
#    A  B  C
# 0  0  0  0
# 1  6  3  0
# 2  1  2  4

# %% [markdown]
# ##pow

# %%
df.pow(df.iloc[0])
# Out:
#           A       B          C
# 0  16777216   46656  387420489
# 1   1679616  531441  387420489
# 2  43046721      64     262144

# %%
row=df.iloc[0,::2]
row
# Out:
# A    8
# C    9
# Name: 0, dtype: int64

# %%
df-row
# Out:
#      A   B    C
# 0  0.0 NaN  0.0
# 1 -2.0 NaN  0.0
# 2  1.0 NaN -5.0

# %% [markdown]
# # 정렬

# %%
s=pd.Series(range(5), index=['A','D','B','C','E'])
s
# Out:
# A    0
# D    1
# B    2
# C    3
# E    4
# dtype: int64

# %%
s.sort_index()
# Out:
# A    0
# B    2
# C    3
# D    1
# E    4
# dtype: int64

# %%
s.sort_values()
# Out:
# A    0
# D    1
# B    2
# C    3
# E    4
# dtype: int64

# %%
df = pd.DataFrame(np.random.randint(0,10,(4,4)),
                   index=[2,4,1,3],
                  columns=list('BDAC'))
df
# Out:
#    B  D  A  C
# 2  4  8  9  2
# 4  3  8  6  2
# 1  8  6  8  6
# 3  7  1  6  5

# %%
df.sort_index()
# Out:
#    B  D  A  C
# 1  8  6  8  6
# 2  4  8  9  2
# 3  7  1  6  5
# 4  3  8  6  2

# %%
df.sort_values(by='A')
# Out:
#    B  D  A  C
# 4  3  8  6  2
# 3  7  1  6  5
# 1  8  6  8  6
# 2  4  8  9  2

# %%
df.sort_values(by=['A','C'])
# Out:
#    B  D  A  C
# 4  3  8  6  2
# 3  7  1  6  5
# 1  8  6  8  6
# 2  4  8  9  2

# %%
df.sort_values(by=['A','C'])
# Out:
#    B  D  A  C
# 4  3  8  6  2
# 3  7  1  6  5
# 1  8  6  8  6
# 2  4  8  9  2

# %% [markdown]
# #순위
