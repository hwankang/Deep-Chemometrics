# %% [markdown]
# <a href="https://colab.research.google.com/github/hwankang/Deep-Chemometrics/blob/master/17(tues)_Jan_2_00_pm__R2%3D0_495_NIR_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #The program of deep learning with A_NIR Data
# ##R2=0.495

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
filename_a='/content/drive/MyDrive/machine_learning/A_NIR_DATA_csv.csv'
X2_df = pd.read_csv(filename_a,header=0, 
                   encoding="unicode-escape")
X2_df
# Out:
# Mounted at /content/drive
#       Unnamed: 0  ¸ðµ¨ Æ÷ÇÔ    Y_A  899.9280058  900.2520706  900.5763689  \
# 0              1       True  24.00     0.098681     0.100515     0.102056
# 1              2       True  24.00     0.098081     0.099926     0.101394
# 2              3       True  24.00     0.089885     0.092072     0.094055
# 3              4       True  23.60     0.088701     0.090287     0.091825
# 4              5       True  23.60     0.095273     0.096945     0.098684
# ...          ...        ...    ...          ...          ...          ...
# 2034        2035       True  25.52     0.076506     0.075591     0.074629
# 2035        2036       True  25.52     0.071916     0.071201     0.070450
# 2036        2037       True  25.37     0.055557     0.054680     0.053789
# 2037        2038       True  25.37     0.050590     0.049846     0.049057
# 2038        2039       True  25.37     0.063837     0.062890     0.062142
#
#       900.9009009  901.2256669  901.5506671  901.8759019  ...  2477.700694  \
# 0        0.100267     0.096954     0.096161     0.097151  ...     2.968741
# 1        0.099664     0.096598     0.095915     0.096567  ...     2.960005
# 2        0.092618     0.089560     0.088900     0.089790  ...     2.943931
# 3        0.090534     0.087883     0.087348     0.088151  ...     2.935452
# 4        0.097460     0.094674     0.093949     0.094563  ...     2.966199
# ...           ...          ...          ...          ...  ...          ...
# 2034     0.072980     0.072275     0.072979     0.072688  ...     2.962918
# 2035     0.068871     0.068104     0.068746     0.068455  ...     2.982798
# 2036     0.052091     0.051338     0.052176     0.052068  ...     2.960384
# 2037     0.047327     0.046489     0.047292     0.047258  ...     2.968252
# 2038     0.060671     0.060073     0.060987     0.060884  ...     2.981493
#
#       2480.15873  2482.621648  2485.089463  2487.562189  2490.039841  \
# 0       2.968988     2.958685     2.950201     2.950122     2.948725
# 1       2.959948     2.951504     2.945633     2.947553     2.947326
# 2       2.943679     2.930295     2.919846     2.920668     2.922776
# 3       2.938259     2.928736     2.921757     2.924166     2.924666
# 4       2.968021     2.955198     2.942411     2.943006     2.942151
# ...          ...          ...          ...          ...          ...
# 2034    2.970997     2.967865     2.957785     2.952054     2.949278
# 2035    2.982529     2.968697     2.958179     2.962882     2.967330
# 2036    2.958313     2.946722     2.938467     2.936874     2.936340
# 2037    2.967836     2.953877     2.942397     2.945923     2.948910
# 2038    2.981399     2.970350     2.962294     2.963960     2.962348
#
#       2492.522433  2495.00998  2497.502498      2500
# 0        2.939113    2.929406     2.929555  2.927579
# 1        2.937901    2.926926     2.924102  2.920722
# 2        2.913596    2.904503     2.903535  2.901086
# 3        2.914831    2.905151     2.902643  2.897351
# 4        2.931640    2.918549     2.918717  2.917849
# ...           ...         ...          ...       ...
# 2034     2.941087    2.935639     2.936698  2.938116
# 2035     2.958188    2.948901     2.948394  2.943151
# 2036     2.925951    2.920350     2.921682  2.917657
# 2037     2.940729    2.926084     2.923839  2.919868
# 2038     2.953168    2.948091     2.949026  2.943110
#
# [2039 rows x 1782 columns]

# %%
X3_df=X2_df.iloc[:,3:]
X3_df
# Out:
#       899.9280058  900.2520706  900.5763689  900.9009009  901.2256669  \
# 0        0.098681     0.100515     0.102056     0.100267     0.096954
# 1        0.098081     0.099926     0.101394     0.099664     0.096598
# 2        0.089885     0.092072     0.094055     0.092618     0.089560
# 3        0.088701     0.090287     0.091825     0.090534     0.087883
# 4        0.095273     0.096945     0.098684     0.097460     0.094674
# ...           ...          ...          ...          ...          ...
# 2034     0.076506     0.075591     0.074629     0.072980     0.072275
# 2035     0.071916     0.071201     0.070450     0.068871     0.068104
# 2036     0.055557     0.054680     0.053789     0.052091     0.051338
# 2037     0.050590     0.049846     0.049057     0.047327     0.046489
# 2038     0.063837     0.062890     0.062142     0.060671     0.060073
#
#       901.5506671  901.8759019  902.2013713  902.5270758  902.8530155  ...  \
# 0        0.096161     0.097151     0.096790     0.095622     0.095521  ...
# 1        0.095915     0.096567     0.095609     0.094073     0.093994  ...
# 2        0.088900     0.089790     0.089088     0.087585     0.087353  ...
# 3        0.087348     0.088151     0.087593     0.086458     0.086425  ...
# 4        0.093949     0.094563     0.093743     0.092318     0.092116  ...
# ...           ...          ...          ...          ...          ...  ...
# 2034     0.072979     0.072688     0.070171     0.068566     0.069321  ...
# 2035     0.068746     0.068455     0.065891     0.064076     0.064532  ...
# 2036     0.052176     0.052068     0.049510     0.047720     0.048518  ...
# 2037     0.047292     0.047258     0.044905     0.043365     0.044220  ...
# 2038     0.060987     0.060884     0.058203     0.056162     0.056647  ...
#
#       2477.700694  2480.15873  2482.621648  2485.089463  2487.562189  \
# 0        2.968741    2.968988     2.958685     2.950201     2.950122
# 1        2.960005    2.959948     2.951504     2.945633     2.947553
# 2        2.943931    2.943679     2.930295     2.919846     2.920668
# 3        2.935452    2.938259     2.928736     2.921757     2.924166
# 4        2.966199    2.968021     2.955198     2.942411     2.943006
# ...           ...         ...          ...          ...          ...
# 2034     2.962918    2.970997     2.967865     2.957785     2.952054
# 2035     2.982798    2.982529     2.968697     2.958179     2.962882
# 2036     2.960384    2.958313     2.946722     2.938467     2.936874
# 2037     2.968252    2.967836     2.953877     2.942397     2.945923
# 2038     2.981493    2.981399     2.970350     2.962294     2.963960
#
#       2490.039841  2492.522433  2495.00998  2497.502498      2500
# 0        2.948725     2.939113    2.929406     2.929555  2.927579
# 1        2.947326     2.937901    2.926926     2.924102  2.920722
# 2        2.922776     2.913596    2.904503     2.903535  2.901086
# 3        2.924666     2.914831    2.905151     2.902643  2.897351
# 4        2.942151     2.931640    2.918549     2.918717  2.917849
# ...           ...          ...         ...          ...       ...
# 2034     2.949278     2.941087    2.935639     2.936698  2.938116
# 2035     2.967330     2.958188    2.948901     2.948394  2.943151
# 2036     2.936340     2.925951    2.920350     2.921682  2.917657
# 2037     2.948910     2.940729    2.926084     2.923839  2.919868
# 2038     2.962348     2.953168    2.948091     2.949026  2.943110
#
# [2039 rows x 1779 columns]

# %%
#special run
#X_df_1=X3_df.iloc[39:,:]
#X_df_2=X3_df.iloc[18:39,:]
#X_df_3=X3_df.iloc[0:18,:]
#X_df_1=X3_df.iloc[400:,:]
#X_df_2=X3_df.iloc[200:400,:]
#X_df_3=X3_df.iloc[0:200,:]
X_df_1=X3_df.iloc[200:,:]
X_df_2=X3_df.iloc[100:200,:]
X_df_3=X3_df.iloc[0:100,:]
X_train_df=X_df_1
X_val_df=X_df_2
X_test_df=X_df_3

# %%
Y3_df=X2_df.iloc[:,2:3]
Y3_df
# Out:
#         Y_A
# 0     24.00
# 1     24.00
# 2     24.00
# 3     23.60
# 4     23.60
# ...     ...
# 2034  25.52
# 2035  25.52
# 2036  25.37
# 2037  25.37
# 2038  25.37
#
# [2039 rows x 1 columns]

# %%
#Y_df_1=Y3_df.iloc[39:,:]
#Y_df_2=Y3_df.iloc[18:39,:]
#Y_df_3=Y3_df.iloc[0:18,:]
#Y_df_1=Y3_df.iloc[400:,:]
#Y_df_2=Y3_df.iloc[200:400,:]
#Y_df_3=Y3_df.iloc[0:200,:]
Y_df_1=Y3_df.iloc[200:,:]
Y_df_2=Y3_df.iloc[100:200,:]
Y_df_3=Y3_df.iloc[0:100,:]
y_train_df=Y_df_1
y_val_df=Y_df_2
y_test_df=Y_df_3

# %%
X_train_val_df=X_train_df.append(X_val_df)
X_train_val=X_train_val_df.values
X_train_a=X_train_df.values
X_val_a=X_val_df.values
X_test_a=X_test_df.values
y_train=y_train_df.values
y_val=y_val_df.values
y_test=y_test_df.values

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
#X_train_val=X_train_a.append(X_val_a)
#std.fit(X_train_val)
std.fit(X_train_a)
X_train=std.transform(X_train_a)
#std.fit(X_val_a)
X_val=std.transform(X_val_a)
#std.fit(X_test_a)
X_test=std.transform(X_test_a)

# %%
dn=X3_df.keys().to_numpy()
dn
axisscale=dn.astype('float')
axisscale
#array(['899.9280058', '900.2520706', '900.5763689', ..., '2495.00998',
#       '2497.502498', '2500'], dtype=object)
# Out:
# array([ 899.9280058,  900.2520706,  900.5763689, ..., 2495.00998  ,
#        2497.502498 , 2500.       ])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(axisscale,X_train.T)
plt.xlabel('nm')
plt.ylabel('normalized intensity')
plt.title('Normalized training data')
plt.show()

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv1D, Reshape#, MaxPooling1D
from keras.callbacks import ReduceLROnPlateau
from keras.layers.noise import GaussianNoise

# %%
#Hyperparameters for the network
DENSE = 128
#DROPOUT = 0.025
DROPOUT = 0
C1_K  = 8 #Number of kernels/feature extractors for first layer
C1_S  = 32 #Width of the convolutional mini networks
C2_K  = 16
C2_S  = 32

activation='relu'
#activation='sigmoid'

input_dim = X_train.shape[1]

#The model
def make_model():
    model = Sequential()
    #Adding a bit of GaussianNoise also works as regularization
    #model.add(GaussianNoise(0.05, input_shape=(input_dim,)))
    #model.add(GaussianNoise(0.005, input_shape=(input_dim,)))
    model.add(GaussianNoise(0.004, input_shape=(input_dim,)))
    #First two is number of filter + kernel size
    model.add(Reshape((input_dim, 1)))
    #model.add(Conv1D(C1_K, (C1_S), activation=activation, border_mode='same'))
    #model.add(Conv1D(C2_K, (C2_S), border_mode='same', activation=activation))
    model.add(Conv1D(C1_K, (C1_S), activation=activation, padding='same'))
    model.add(Conv1D(C2_K, (C2_S), padding='same', activation=activation))
    model.add(Flatten())
    model.add(Dropout(DROPOUT))
    model.add(Dense(DENSE, activation=activation))
    model.add(Dense(1, activation='linear'))

    #model.compile(loss='mse', optimizer=keras.optimizers.Adadelta(lr=0.01))#, metrics=['mean_absolute_error'])
    model.compile(loss='mse', optimizer=keras.optimizers.Adam(lr=0.002))#, metrics=['mean_absolute_error'])

    return model

# %%
model = make_model()
print(model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gaussian_noise_6 (GaussianN  (None, 1779)             0
#  oise)
#
#  reshape_6 (Reshape)         (None, 1779, 1)           0
#
#  conv1d_12 (Conv1D)          (None, 1779, 8)           264
#
#  conv1d_13 (Conv1D)          (None, 1779, 16)          4112
#
#  flatten_6 (Flatten)         (None, 28464)             0
#
#  dropout_6 (Dropout)         (None, 28464)             0
#
#  dense_12 (Dense)            (None, 128)               3643520
#
#  dense_13 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 3,648,025
# Trainable params: 3,648,025
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
h = model.fit(X_train, y_train, epochs=100, batch_size=8, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 230/230 [==============================] - 17s 70ms/step - loss: 163.2676 - val_loss: 40.8268
# Epoch 2/100
# 230/230 [==============================] - 16s 69ms/step - loss: 21.3879 - val_loss: 41.9961
# Epoch 3/100
# 230/230 [==============================] - 16s 71ms/step - loss: 15.6204 - val_loss: 26.8978
# Epoch 4/100
# 230/230 [==============================] - 16s 68ms/step - loss: 15.2475 - val_loss: 41.6898
# Epoch 5/100
# 230/230 [==============================] - 16s 69ms/step - loss: 11.8985 - val_loss: 26.2111
# Epoch 6/100
# 230/230 [==============================] - 16s 69ms/step - loss: 11.1172 - val_loss: 21.6067
# Epoch 7/100
# 230/230 [==============================] - 16s 69ms/step - loss: 10.4358 - val_loss: 25.3113
# Epoch 8/100
# 230/230 [==============================] - 15s 66ms/step - loss: 12.0060 - val_loss: 19.2234
# Epoch 9/100
# 230/230 [==============================] - 16s 68ms/step - loss: 9.4326 - val_loss: 22.0591
# Epoch 10/100
# 230/230 [==============================] - 16s 69ms/step - loss: 9.3628 - val_loss: 14.3083
# Epoch 11/100
# 230/230 [==============================] - 16s 70ms/step - loss: 7.0257 - val_loss: 21.8446
# Epoch 12/100
# 230/230 [==============================] - 16s 71ms/step - loss: 6.9072 - val_loss: 18.5692
# Epoch 13/100
# 230/230 [==============================] - 16s 71ms/step - loss: 6.5200 - val_loss: 22.1399
# Epoch 14/100
# 230/230 [==============================] - 16s 71ms/step - loss: 6.9119 - val_loss: 16.9417
# Epoch 15/100
# 230/230 [==============================] - 15s 67ms/step - loss: 6.4348 - val_loss: 13.6244
# Epoch 16/100
# 230/230 [==============================] - 16s 68ms/step - loss: 5.3721 - val_loss: 25.1193
# Epoch 17/100
# 230/230 [==============================] - 16s 70ms/step - loss: 5.4957 - val_loss: 13.5885
# Epoch 18/100
# 230/230 [==============================] - 15s 67ms/step - loss: 4.7753 - val_loss: 19.9363
# Epoch 19/100
# 230/230 [==============================] - 16s 68ms/step - loss: 5.0915 - val_loss: 15.0076
# Epoch 20/100
# 230/230 [==============================] - 17s 73ms/step - loss: 5.2410 - val_loss: 16.6451
# Epoch 21/100
# 230/230 [==============================] - 16s 71ms/step - loss: 4.5823 - val_loss: 15.3927
# Epoch 22/100
# 230/230 [==============================] - 15s 67ms/step - loss: 4.9675 - val_loss: 14.9079
# Epoch 23/100
# 230/230 [==============================] - 15s 64ms/step - loss: 4.9286 - val_loss: 22.3986
# Epoch 24/100
# 230/230 [==============================] - 15s 65ms/step - loss: 5.6241 - val_loss: 18.1127
# Epoch 25/100
# 230/230 [==============================] - 16s 67ms/step - loss: 3.9041 - val_loss: 15.1158
# Epoch 26/100
# 230/230 [==============================] - 16s 69ms/step - loss: 4.5229 - val_loss: 16.3635
# Epoch 27/100
# 230/230 [==============================] - 16s 67ms/step - loss: 3.9952 - val_loss: 12.9003
# Epoch 28/100
# 230/230 [==============================] - 15s 67ms/step - loss: 4.5366 - val_loss: 16.2191
# Epoch 29/100
# 230/230 [==============================] - 15s 65ms/step - loss: 5.1211 - val_loss: 20.1194
# Epoch 30/100
# 230/230 [==============================] - 15s 67ms/step - loss: 3.9064 - val_loss: 14.2969
# Epoch 31/100
# 230/230 [==============================] - 16s 70ms/step - loss: 5.7818 - val_loss: 20.8445
# Epoch 32/100
# 230/230 [==============================] - 15s 67ms/step - loss: 6.2628 - val_loss: 16.8523
# Epoch 33/100
# 230/230 [==============================] - 16s 68ms/step - loss: 5.2526 - val_loss: 12.4080
# Epoch 34/100
# 230/230 [==============================] - 15s 66ms/step - loss: 4.8814 - val_loss: 14.7204
# Epoch 35/100
# 230/230 [==============================] - 16s 68ms/step - loss: 3.2644 - val_loss: 12.5914
# Epoch 36/100
# 230/230 [==============================] - 16s 71ms/step - loss: 3.1264 - val_loss: 12.9097
# Epoch 37/100
# 230/230 [==============================] - 16s 70ms/step - loss: 3.3768 - val_loss: 15.7830
# Epoch 38/100
# 230/230 [==============================] - 15s 65ms/step - loss: 9.5203 - val_loss: 21.5680
# Epoch 39/100
# 230/230 [==============================] - 16s 70ms/step - loss: 6.8102 - val_loss: 14.9710
# Epoch 40/100
# 230/230 [==============================] - 16s 69ms/step - loss: 3.4238 - val_loss: 22.4808
# Epoch 41/100
# 230/230 [==============================] - 16s 68ms/step - loss: 3.8066 - val_loss: 15.1776
# Epoch 42/100
# 230/230 [==============================] - 15s 67ms/step - loss: 2.7927 - val_loss: 14.2570
# Epoch 43/100
# 230/230 [==============================] - 15s 65ms/step - loss: 3.1520 - val_loss: 16.6243
# Epoch 44/100
# 230/230 [==============================] - 15s 65ms/step - loss: 4.0445 - val_loss: 17.1927
# Epoch 45/100
# 230/230 [==============================] - 17s 72ms/step - loss: 2.7109 - val_loss: 16.0308
# Epoch 46/100
# 230/230 [==============================] - 15s 64ms/step - loss: 2.8480 - val_loss: 14.0632
# Epoch 47/100
# 230/230 [==============================] - 16s 69ms/step - loss: 2.8806 - val_loss: 18.0579
# Epoch 48/100
# 230/230 [==============================] - 15s 64ms/step - loss: 2.4524 - val_loss: 12.6409
# Epoch 49/100
# 230/230 [==============================] - 16s 69ms/step - loss: 2.9770 - val_loss: 15.6897
# Epoch 50/100
# 230/230 [==============================] - 15s 66ms/step - loss: 3.5331 - val_loss: 15.3756
# Epoch 51/100
# 230/230 [==============================] - 17s 72ms/step - loss: 6.1837 - val_loss: 15.7908
# Epoch 52/100
# 230/230 [==============================] - 16s 71ms/step - loss: 3.5421 - val_loss: 25.6574
# Epoch 53/100
# 230/230 [==============================] - 16s 71ms/step - loss: 3.8244 - val_loss: 17.1202
# Epoch 54/100
# 230/230 [==============================] - 15s 66ms/step - loss: 3.4843 - val_loss: 21.0190
# Epoch 55/100
# 230/230 [==============================] - 16s 68ms/step - loss: 3.5792 - val_loss: 12.5120
# Epoch 56/100
# 230/230 [==============================] - 15s 66ms/step - loss: 2.4373 - val_loss: 14.9490
# Epoch 57/100
# 230/230 [==============================] - 16s 69ms/step - loss: 2.6360 - val_loss: 16.2924
# Epoch 58/100
# 230/230 [==============================] - 16s 68ms/step - loss: 8.2752 - val_loss: 24.9560
# Epoch 59/100
# 230/230 [==============================] - 15s 66ms/step - loss: 5.0840 - val_loss: 24.4193
# Epoch 60/100
# 230/230 [==============================] - 15s 67ms/step - loss: 2.6166 - val_loss: 13.8072
# Epoch 61/100
# 230/230 [==============================] - 15s 67ms/step - loss: 2.3714 - val_loss: 15.3940
# Epoch 62/100
# 230/230 [==============================] - 15s 67ms/step - loss: 2.4713 - val_loss: 16.1795
# Epoch 63/100
# 230/230 [==============================] - 16s 69ms/step - loss: 2.4515 - val_loss: 15.4309
# Epoch 64/100
# 230/230 [==============================] - 15s 67ms/step - loss: 2.4399 - val_loss: 14.8601
# Epoch 65/100
# 230/230 [==============================] - 16s 68ms/step - loss: 2.1865 - val_loss: 15.7363
# Epoch 66/100
# 230/230 [==============================] - 15s 65ms/step - loss: 2.6162 - val_loss: 15.4378
# Epoch 67/100
# 230/230 [==============================] - 16s 71ms/step - loss: 1.8767 - val_loss: 13.6558
# Epoch 68/100
# 230/230 [==============================] - 15s 66ms/step - loss: 1.6709 - val_loss: 13.6677
# Epoch 69/100
# 230/230 [==============================] - 16s 68ms/step - loss: 1.8680 - val_loss: 13.4672
# Epoch 70/100
# 230/230 [==============================] - 15s 67ms/step - loss: 2.7381 - val_loss: 16.3305
# Epoch 71/100
# 230/230 [==============================] - 16s 68ms/step - loss: 1.6264 - val_loss: 12.9467
# Epoch 72/100
# 230/230 [==============================] - 16s 69ms/step - loss: 1.8033 - val_loss: 13.3294
# Epoch 73/100
# 230/230 [==============================] - 16s 70ms/step - loss: 1.7920 - val_loss: 11.9324
# Epoch 74/100
# 230/230 [==============================] - 16s 69ms/step - loss: 1.7046 - val_loss: 14.0571
# Epoch 75/100
# 230/230 [==============================] - 16s 69ms/step - loss: 1.7006 - val_loss: 14.7298
# Epoch 76/100
# 230/230 [==============================] - 16s 72ms/step - loss: 3.3025 - val_loss: 14.8024
# Epoch 77/100
# 230/230 [==============================] - 16s 70ms/step - loss: 1.9716 - val_loss: 14.0510
# Epoch 78/100
# 230/230 [==============================] - 16s 69ms/step - loss: 1.7354 - val_loss: 13.9277
# Epoch 79/100
# 230/230 [==============================] - 15s 66ms/step - loss: 1.4921 - val_loss: 15.3424
# Epoch 80/100
# 230/230 [==============================] - 15s 65ms/step - loss: 1.7294 - val_loss: 14.5427
# Epoch 81/100
# 230/230 [==============================] - 16s 69ms/step - loss: 1.1782 - val_loss: 14.5178
# Epoch 82/100
# 230/230 [==============================] - 16s 71ms/step - loss: 1.4110 - val_loss: 12.6795
# Epoch 83/100
# 230/230 [==============================] - 16s 69ms/step - loss: 1.2556 - val_loss: 15.3710
# Epoch 84/100
# 230/230 [==============================] - 16s 72ms/step - loss: 1.6988 - val_loss: 23.5366
# Epoch 85/100
# 230/230 [==============================] - 17s 72ms/step - loss: 1.9986 - val_loss: 12.6794
# Epoch 86/100
# 230/230 [==============================] - 16s 70ms/step - loss: 1.4170 - val_loss: 14.5685
# Epoch 87/100
# 230/230 [==============================] - 16s 69ms/step - loss: 1.3304 - val_loss: 16.5836
# Epoch 88/100
# 230/230 [==============================] - 16s 71ms/step - loss: 1.6928 - val_loss: 16.2178
# Epoch 89/100
# 230/230 [==============================] - 16s 71ms/step - loss: 1.6020 - val_loss: 15.4314
# Epoch 90/100
# 230/230 [==============================] - 16s 68ms/step - loss: 2.3011 - val_loss: 13.5662
# Epoch 91/100
# 230/230 [==============================] - 16s 69ms/step - loss: 2.2763 - val_loss: 12.9347
# Epoch 92/100
# 230/230 [==============================] - 16s 69ms/step - loss: 1.3212 - val_loss: 13.1120
# Epoch 93/100
# 230/230 [==============================] - 16s 68ms/step - loss: 1.1472 - val_loss: 13.7849
# Epoch 94/100
# 230/230 [==============================] - 17s 74ms/step - loss: 1.0825 - val_loss: 14.2422
# Epoch 95/100
# 230/230 [==============================] - 15s 66ms/step - loss: 1.5205 - val_loss: 13.1991
# Epoch 96/100
# 230/230 [==============================] - 16s 71ms/step - loss: 1.3134 - val_loss: 14.4972
# Epoch 97/100
# 230/230 [==============================] - 16s 68ms/step - loss: 5.7116 - val_loss: 14.5345
# Epoch 98/100
# 230/230 [==============================] - 16s 67ms/step - loss: 1.2643 - val_loss: 15.3394
# Epoch 99/100
# 230/230 [==============================] - 17s 73ms/step - loss: 1.1115 - val_loss: 15.3406
# Epoch 100/100
# 230/230 [==============================] - 16s 71ms/step - loss: 0.8888 - val_loss: 14.8109

# %%
#import matplotlib.psplot as plt
import matplotlib.pyplot as plt
plt.plot(h.history['loss'], label='loss')
plt.plot(h.history['val_loss'], label='val_loss')

plt.yscale('log')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
ax2 = plt.gca().twinx()
ax2.plot(h.history['lr'], color='r')
ax2.set_ylabel('lr',color='r')

_ = plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-f0efbcbef879> in <module>
#       9 plt.legend()
#      10 ax2 = plt.gca().twinx()
# ---> 11 ax2.plot(h.history['lr'], color='r')
#      12 ax2.set_ylabel('lr',color='r')
#      13
#
# KeyError: 'lr'

# %%
plt.scatter(y_train, model.predict(X_train))
plt.scatter(y_val, model.predict(X_val))
plt.scatter(y_test, model.predict(X_test))
plt.plot([0,30],[0,30]) # Y = PredY line
plt.xlabel('true value')
plt.ylabel('predicted value')
# Out:
# 58/58 [==============================] - 2s 29ms/step
# 4/4 [==============================] - 0s 26ms/step
# 4/4 [==============================] - 0s 25ms/step
# Text(0, 0.5, 'predicted value')

# %%
pred_Y_df=model.predict(X_test)
Y_df_true=y_test
from sklearn.metrics import mean_squared_error, r2_score
mse= mean_squared_error(Y_df_true, pred_Y_df)
rmse=np.sqrt(mse)
r2=r2_score(Y_df_true, pred_Y_df)
print('MSE : {: 0.3f}, || RMSE : {: 0.3f}, || R2 : {: 0.3f}'.format(mse,rmse,r2))
# Out:
# 4/4 [==============================] - 0s 24ms/step
# MSE :  20.238, || RMSE :  4.499, || R2 :  0.495

# %% [markdown]
# #The end of program
