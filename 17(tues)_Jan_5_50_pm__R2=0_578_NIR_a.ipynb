# %% [markdown]
# <a href="https://colab.research.google.com/github/hwankang/Deep-Chemometrics/blob/master/17(tues)_Jan_5_50_pm__R2%3D0_578_NIR_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #The program of deep learning with A_NIR Data

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
filename_a='/content/drive/MyDrive/machine_learning/A_NIR_DATA_csv.csv'
X2_df = pd.read_csv(filename_a,header=0, 
                   encoding="unicode-escape")
X2_df
# Out:
# Mounted at /content/drive
#       Unnamed: 0  ¸ðµ¨ Æ÷ÇÔ    Y_A  899.9280058  900.2520706  900.5763689  \
# 0              1       True  24.00     0.098681     0.100515     0.102056
# 1              2       True  24.00     0.098081     0.099926     0.101394
# 2              3       True  24.00     0.089885     0.092072     0.094055
# 3              4       True  23.60     0.088701     0.090287     0.091825
# 4              5       True  23.60     0.095273     0.096945     0.098684
# ...          ...        ...    ...          ...          ...          ...
# 2034        2035       True  25.52     0.076506     0.075591     0.074629
# 2035        2036       True  25.52     0.071916     0.071201     0.070450
# 2036        2037       True  25.37     0.055557     0.054680     0.053789
# 2037        2038       True  25.37     0.050590     0.049846     0.049057
# 2038        2039       True  25.37     0.063837     0.062890     0.062142
#
#       900.9009009  901.2256669  901.5506671  901.8759019  ...  2477.700694  \
# 0        0.100267     0.096954     0.096161     0.097151  ...     2.968741
# 1        0.099664     0.096598     0.095915     0.096567  ...     2.960005
# 2        0.092618     0.089560     0.088900     0.089790  ...     2.943931
# 3        0.090534     0.087883     0.087348     0.088151  ...     2.935452
# 4        0.097460     0.094674     0.093949     0.094563  ...     2.966199
# ...           ...          ...          ...          ...  ...          ...
# 2034     0.072980     0.072275     0.072979     0.072688  ...     2.962918
# 2035     0.068871     0.068104     0.068746     0.068455  ...     2.982798
# 2036     0.052091     0.051338     0.052176     0.052068  ...     2.960384
# 2037     0.047327     0.046489     0.047292     0.047258  ...     2.968252
# 2038     0.060671     0.060073     0.060987     0.060884  ...     2.981493
#
#       2480.15873  2482.621648  2485.089463  2487.562189  2490.039841  \
# 0       2.968988     2.958685     2.950201     2.950122     2.948725
# 1       2.959948     2.951504     2.945633     2.947553     2.947326
# 2       2.943679     2.930295     2.919846     2.920668     2.922776
# 3       2.938259     2.928736     2.921757     2.924166     2.924666
# 4       2.968021     2.955198     2.942411     2.943006     2.942151
# ...          ...          ...          ...          ...          ...
# 2034    2.970997     2.967865     2.957785     2.952054     2.949278
# 2035    2.982529     2.968697     2.958179     2.962882     2.967330
# 2036    2.958313     2.946722     2.938467     2.936874     2.936340
# 2037    2.967836     2.953877     2.942397     2.945923     2.948910
# 2038    2.981399     2.970350     2.962294     2.963960     2.962348
#
#       2492.522433  2495.00998  2497.502498      2500
# 0        2.939113    2.929406     2.929555  2.927579
# 1        2.937901    2.926926     2.924102  2.920722
# 2        2.913596    2.904503     2.903535  2.901086
# 3        2.914831    2.905151     2.902643  2.897351
# 4        2.931640    2.918549     2.918717  2.917849
# ...           ...         ...          ...       ...
# 2034     2.941087    2.935639     2.936698  2.938116
# 2035     2.958188    2.948901     2.948394  2.943151
# 2036     2.925951    2.920350     2.921682  2.917657
# 2037     2.940729    2.926084     2.923839  2.919868
# 2038     2.953168    2.948091     2.949026  2.943110
#
# [2039 rows x 1782 columns]

# %%
X3_df=X2_df.iloc[:,3:]
X3_df
# Out:
#       899.9280058  900.2520706  900.5763689  900.9009009  901.2256669  \
# 0        0.098681     0.100515     0.102056     0.100267     0.096954
# 1        0.098081     0.099926     0.101394     0.099664     0.096598
# 2        0.089885     0.092072     0.094055     0.092618     0.089560
# 3        0.088701     0.090287     0.091825     0.090534     0.087883
# 4        0.095273     0.096945     0.098684     0.097460     0.094674
# ...           ...          ...          ...          ...          ...
# 2034     0.076506     0.075591     0.074629     0.072980     0.072275
# 2035     0.071916     0.071201     0.070450     0.068871     0.068104
# 2036     0.055557     0.054680     0.053789     0.052091     0.051338
# 2037     0.050590     0.049846     0.049057     0.047327     0.046489
# 2038     0.063837     0.062890     0.062142     0.060671     0.060073
#
#       901.5506671  901.8759019  902.2013713  902.5270758  902.8530155  ...  \
# 0        0.096161     0.097151     0.096790     0.095622     0.095521  ...
# 1        0.095915     0.096567     0.095609     0.094073     0.093994  ...
# 2        0.088900     0.089790     0.089088     0.087585     0.087353  ...
# 3        0.087348     0.088151     0.087593     0.086458     0.086425  ...
# 4        0.093949     0.094563     0.093743     0.092318     0.092116  ...
# ...           ...          ...          ...          ...          ...  ...
# 2034     0.072979     0.072688     0.070171     0.068566     0.069321  ...
# 2035     0.068746     0.068455     0.065891     0.064076     0.064532  ...
# 2036     0.052176     0.052068     0.049510     0.047720     0.048518  ...
# 2037     0.047292     0.047258     0.044905     0.043365     0.044220  ...
# 2038     0.060987     0.060884     0.058203     0.056162     0.056647  ...
#
#       2477.700694  2480.15873  2482.621648  2485.089463  2487.562189  \
# 0        2.968741    2.968988     2.958685     2.950201     2.950122
# 1        2.960005    2.959948     2.951504     2.945633     2.947553
# 2        2.943931    2.943679     2.930295     2.919846     2.920668
# 3        2.935452    2.938259     2.928736     2.921757     2.924166
# 4        2.966199    2.968021     2.955198     2.942411     2.943006
# ...           ...         ...          ...          ...          ...
# 2034     2.962918    2.970997     2.967865     2.957785     2.952054
# 2035     2.982798    2.982529     2.968697     2.958179     2.962882
# 2036     2.960384    2.958313     2.946722     2.938467     2.936874
# 2037     2.968252    2.967836     2.953877     2.942397     2.945923
# 2038     2.981493    2.981399     2.970350     2.962294     2.963960
#
#       2490.039841  2492.522433  2495.00998  2497.502498      2500
# 0        2.948725     2.939113    2.929406     2.929555  2.927579
# 1        2.947326     2.937901    2.926926     2.924102  2.920722
# 2        2.922776     2.913596    2.904503     2.903535  2.901086
# 3        2.924666     2.914831    2.905151     2.902643  2.897351
# 4        2.942151     2.931640    2.918549     2.918717  2.917849
# ...           ...          ...         ...          ...       ...
# 2034     2.949278     2.941087    2.935639     2.936698  2.938116
# 2035     2.967330     2.958188    2.948901     2.948394  2.943151
# 2036     2.936340     2.925951    2.920350     2.921682  2.917657
# 2037     2.948910     2.940729    2.926084     2.923839  2.919868
# 2038     2.962348     2.953168    2.948091     2.949026  2.943110
#
# [2039 rows x 1779 columns]

# %%
#special run
#X_df_1=X3_df.iloc[39:,:]
#X_df_2=X3_df.iloc[18:39,:]
#X_df_3=X3_df.iloc[0:18,:]
#X_df_1=X3_df.iloc[400:,:]
#X_df_2=X3_df.iloc[200:400,:]
#X_df_3=X3_df.iloc[0:200,:]
X_df_1=X3_df.iloc[200:,:]
X_df_2=X3_df.iloc[100:200,:]
X_df_3=X3_df.iloc[0:100,:]
X_train_df=X_df_1
X_val_df=X_df_2
X_test_df=X_df_3

# %%
Y3_df=X2_df.iloc[:,2:3]
Y3_df
# Out:
#         Y_A
# 0     24.00
# 1     24.00
# 2     24.00
# 3     23.60
# 4     23.60
# ...     ...
# 2034  25.52
# 2035  25.52
# 2036  25.37
# 2037  25.37
# 2038  25.37
#
# [2039 rows x 1 columns]

# %%
#Y_df_1=Y3_df.iloc[39:,:]
#Y_df_2=Y3_df.iloc[18:39,:]
#Y_df_3=Y3_df.iloc[0:18,:]
#Y_df_1=Y3_df.iloc[400:,:]
#Y_df_2=Y3_df.iloc[200:400,:]
#Y_df_3=Y3_df.iloc[0:200,:]
Y_df_1=Y3_df.iloc[200:,:]
Y_df_2=Y3_df.iloc[100:200,:]
Y_df_3=Y3_df.iloc[0:100,:]
y_train_df=Y_df_1
y_val_df=Y_df_2
y_test_df=Y_df_3

# %%
#X_train_val_df=X_train_df.append(X_val_df)
#X_train_val=X_train_val_df.values
X_train_a=X_train_df.values
X_val_a=X_val_df.values
X_test_a=X_test_df.values
y_train=y_train_df.values
y_val=y_val_df.values
y_test=y_test_df.values

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
#X_train_val=X_train_a.append(X_val_a)
#std.fit(X_train_val)
std.fit(X_train_a)
X_train=std.transform(X_train_a)
#std.fit(X_val_a)
X_val=std.transform(X_val_a)
#std.fit(X_test_a)
X_test=std.transform(X_test_a)

# %%
##import matplotlib.pyplot as plt
##%matplotlib inline
##plt.plot(axisscale,X_train.T)
##plt.xlabel('nm')
##plt.ylabel('normalized intensity')
##plt.title('Normalized training data')
##plt.show()

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv1D, Reshape#, MaxPooling1D
from keras.callbacks import ReduceLROnPlateau
from keras.layers.noise import GaussianNoise

# %%
#Hyperparameters for the network
DENSE = 128
#DROPOUT = 0.025
DROPOUT = 0
C1_K  = 8 #Number of kernels/feature extractors for first layer
C1_S  = 32 #Width of the convolutional mini networks
C2_K  = 16
C2_S  = 32

activation='relu'
#activation='sigmoid'

input_dim = X_train.shape[1]

#The model
def make_model():
    model = Sequential()
    #Adding a bit of GaussianNoise also works as regularization
    #model.add(GaussianNoise(0.05, input_shape=(input_dim,)))
    #model.add(GaussianNoise(0.005, input_shape=(input_dim,)))
    model.add(GaussianNoise(0.004, input_shape=(input_dim,)))
    #First two is number of filter + kernel size
    model.add(Reshape((input_dim, 1)))
    #model.add(Conv1D(C1_K, (C1_S), activation=activation, border_mode='same'))
    #model.add(Conv1D(C2_K, (C2_S), border_mode='same', activation=activation))
    model.add(Conv1D(C1_K, (C1_S), activation=activation, padding='same'))
    model.add(Conv1D(C2_K, (C2_S), padding='same', activation=activation))
    model.add(Flatten())
    model.add(Dropout(DROPOUT))
    model.add(Dense(DENSE, activation=activation))
    model.add(Dense(1, activation='linear'))

    #model.compile(loss='mse', optimizer=keras.optimizers.Adadelta(lr=0.01))#, metrics=['mean_absolute_error'])
    model.compile(loss='mse', optimizer=keras.optimizers.Adam(lr=0.002))#, metrics=['mean_absolute_error'])

    return model

# %%
model = make_model()
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gaussian_noise (GaussianNoi  (None, 1779)             0
#  se)
#
#  reshape (Reshape)           (None, 1779, 1)           0
#
#  conv1d (Conv1D)             (None, 1779, 8)           264
#
#  conv1d_1 (Conv1D)           (None, 1779, 16)          4112
#
#  flatten (Flatten)           (None, 28464)             0
#
#  dropout (Dropout)           (None, 28464)             0
#
#  dense (Dense)               (None, 128)               3643520
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3,648,025
# Trainable params: 3,648,025
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
h = model.fit(X_train, y_train, epochs=100, batch_size=8, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 230/230 [==============================] - 9s 5ms/step - loss: 34.5366 - val_loss: 26.7671
# Epoch 2/100
# 230/230 [==============================] - 1s 4ms/step - loss: 11.0929 - val_loss: 20.1163
# Epoch 3/100
# 230/230 [==============================] - 1s 4ms/step - loss: 11.0804 - val_loss: 18.6107
# Epoch 4/100
# 230/230 [==============================] - 1s 4ms/step - loss: 10.4867 - val_loss: 21.1573
# Epoch 5/100
# 230/230 [==============================] - 1s 4ms/step - loss: 7.7535 - val_loss: 13.6945
# Epoch 6/100
# 230/230 [==============================] - 1s 4ms/step - loss: 7.4605 - val_loss: 16.6287
# Epoch 7/100
# 230/230 [==============================] - 1s 4ms/step - loss: 7.3643 - val_loss: 18.4003
# Epoch 8/100
# 230/230 [==============================] - 1s 4ms/step - loss: 12.5423 - val_loss: 19.9576
# Epoch 9/100
# 230/230 [==============================] - 1s 4ms/step - loss: 5.7157 - val_loss: 20.7287
# Epoch 10/100
# 230/230 [==============================] - 1s 4ms/step - loss: 5.5900 - val_loss: 16.6796
# Epoch 11/100
# 230/230 [==============================] - 1s 4ms/step - loss: 5.1016 - val_loss: 12.1480
# Epoch 12/100
# 230/230 [==============================] - 1s 4ms/step - loss: 4.7575 - val_loss: 18.6304
# Epoch 13/100
# 230/230 [==============================] - 1s 4ms/step - loss: 6.2533 - val_loss: 14.6197
# Epoch 14/100
# 230/230 [==============================] - 1s 4ms/step - loss: 5.8849 - val_loss: 14.2770
# Epoch 15/100
# 230/230 [==============================] - 1s 4ms/step - loss: 5.5863 - val_loss: 15.8660
# Epoch 16/100
# 230/230 [==============================] - 1s 4ms/step - loss: 6.2672 - val_loss: 18.7168
# Epoch 17/100
# 230/230 [==============================] - 1s 4ms/step - loss: 4.5466 - val_loss: 14.0082
# Epoch 18/100
# 230/230 [==============================] - 1s 4ms/step - loss: 6.3801 - val_loss: 15.8131
# Epoch 19/100
# 230/230 [==============================] - 1s 4ms/step - loss: 5.9450 - val_loss: 14.6746
# Epoch 20/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.3942 - val_loss: 15.1075
# Epoch 21/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.7618 - val_loss: 13.0938
# Epoch 22/100
# 230/230 [==============================] - 1s 4ms/step - loss: 4.0681 - val_loss: 14.6297
# Epoch 23/100
# 230/230 [==============================] - 1s 4ms/step - loss: 4.6115 - val_loss: 12.5031
# Epoch 24/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.7340 - val_loss: 10.5010
# Epoch 25/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.9279 - val_loss: 15.8582
# Epoch 26/100
# 230/230 [==============================] - 1s 4ms/step - loss: 4.4125 - val_loss: 13.8768
# Epoch 27/100
# 230/230 [==============================] - 1s 4ms/step - loss: 4.9518 - val_loss: 11.8979
# Epoch 28/100
# 230/230 [==============================] - 1s 4ms/step - loss: 4.2863 - val_loss: 19.2452
# Epoch 29/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.7487 - val_loss: 11.4169
# Epoch 30/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.4662 - val_loss: 8.5755
# Epoch 31/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.5140 - val_loss: 12.9932
# Epoch 32/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.7890 - val_loss: 10.2641
# Epoch 33/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.7308 - val_loss: 15.4567
# Epoch 34/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.9616 - val_loss: 15.0123
# Epoch 35/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.1247 - val_loss: 10.6938
# Epoch 36/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.1805 - val_loss: 10.8480
# Epoch 37/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.0771 - val_loss: 10.7605
# Epoch 38/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.9231 - val_loss: 10.6951
# Epoch 39/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.5561 - val_loss: 14.2684
# Epoch 40/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.4757 - val_loss: 14.2968
# Epoch 41/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.0233 - val_loss: 9.2176
# Epoch 42/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.7037 - val_loss: 10.1115
# Epoch 43/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.1628 - val_loss: 8.8166
# Epoch 44/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.4448 - val_loss: 14.7552
# Epoch 45/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.4901 - val_loss: 10.0658
# Epoch 46/100
# 230/230 [==============================] - 1s 4ms/step - loss: 3.4295 - val_loss: 14.8761
# Epoch 47/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.2964 - val_loss: 8.7732
# Epoch 48/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.1978 - val_loss: 7.7017
# Epoch 49/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.1082 - val_loss: 10.6402
# Epoch 50/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.8139 - val_loss: 9.7833
# Epoch 51/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.1629 - val_loss: 12.2976
# Epoch 52/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.0012 - val_loss: 7.3870
# Epoch 53/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.6367 - val_loss: 12.3098
# Epoch 54/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.4526 - val_loss: 8.0722
# Epoch 55/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.1181 - val_loss: 8.9208
# Epoch 56/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.7864 - val_loss: 8.7848
# Epoch 57/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.5539 - val_loss: 10.2914
# Epoch 58/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.9036 - val_loss: 10.0453
# Epoch 59/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.4608 - val_loss: 8.3697
# Epoch 60/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.5857 - val_loss: 9.1256
# Epoch 61/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.0269 - val_loss: 10.5722
# Epoch 62/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.5916 - val_loss: 8.7268
# Epoch 63/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.4365 - val_loss: 11.1551
# Epoch 64/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.8243 - val_loss: 9.8309
# Epoch 65/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.5050 - val_loss: 8.7208
# Epoch 66/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.6431 - val_loss: 8.0145
# Epoch 67/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1113 - val_loss: 9.1789
# Epoch 68/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.2908 - val_loss: 9.0597
# Epoch 69/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1927 - val_loss: 10.5741
# Epoch 70/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.2928 - val_loss: 13.7854
# Epoch 71/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.8778 - val_loss: 13.1704
# Epoch 72/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.8209 - val_loss: 8.3775
# Epoch 73/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.3346 - val_loss: 10.3579
# Epoch 74/100
# 230/230 [==============================] - 1s 4ms/step - loss: 2.6077 - val_loss: 9.4664
# Epoch 75/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.0194 - val_loss: 8.0315
# Epoch 76/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.0861 - val_loss: 9.4405
# Epoch 77/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.7779 - val_loss: 12.1176
# Epoch 78/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.8607 - val_loss: 9.5634
# Epoch 79/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.1687 - val_loss: 10.0251
# Epoch 80/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.9195 - val_loss: 9.8440
# Epoch 81/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.9167 - val_loss: 9.2085
# Epoch 82/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.8804 - val_loss: 8.9708
# Epoch 83/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.8857 - val_loss: 10.2470
# Epoch 84/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.7509 - val_loss: 9.5962
# Epoch 85/100
# 230/230 [==============================] - 1s 4ms/step - loss: 7.4524 - val_loss: 15.5492
# Epoch 86/100
# 230/230 [==============================] - 1s 4ms/step - loss: 5.5069 - val_loss: 13.3556
# Epoch 87/100
# 230/230 [==============================] - 1s 4ms/step - loss: 1.3642 - val_loss: 10.0309
# Epoch 88/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.7431 - val_loss: 9.2127
# Epoch 89/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.5893 - val_loss: 9.6678
# Epoch 90/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.5759 - val_loss: 9.0781
# Epoch 91/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.5292 - val_loss: 11.3605
# Epoch 92/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.4728 - val_loss: 10.0592
# Epoch 93/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.4636 - val_loss: 9.3565
# Epoch 94/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.5253 - val_loss: 9.3856
# Epoch 95/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.6661 - val_loss: 9.5912
# Epoch 96/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.8116 - val_loss: 9.5268
# Epoch 97/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.5435 - val_loss: 9.7308
# Epoch 98/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.7231 - val_loss: 9.3690
# Epoch 99/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.6312 - val_loss: 8.6104
# Epoch 100/100
# 230/230 [==============================] - 1s 4ms/step - loss: 0.7767 - val_loss: 9.0973

# %%
#import matplotlib.psplot as plt
import matplotlib.pyplot as plt
plt.plot(h.history['loss'], label='loss')
plt.plot(h.history['val_loss'], label='val_loss')

plt.yscale('log')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
ax2 = plt.gca().twinx()
#ax2.plot(h.history['lr'], color='r')
ax2.set_ylabel('lr',color='r')

_ = plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.scatter(y_train, model.predict(X_train))
plt.scatter(y_val, model.predict(X_val))
plt.scatter(y_test, model.predict(X_test))
plt.plot([0,30],[0,30]) # Y = PredY line
plt.xlabel('true value')
plt.ylabel('predicted value')
# Out:
# 58/58 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 3ms/step
# Text(0, 0.5, 'predicted value')

# %%
pred_Y_df=model.predict(X_test)
Y_df_true=y_test
from sklearn.metrics import mean_squared_error, r2_score
mse= mean_squared_error(Y_df_true, pred_Y_df)
rmse=np.sqrt(mse)
r2=r2_score(Y_df_true, pred_Y_df)
print('MSE : {: 0.3f}, || RMSE : {: 0.3f}, || R2 : {: 0.3f}'.format(mse,rmse,r2))
# Out:
# 4/4 [==============================] - 0s 3ms/step
# MSE :  16.927, || RMSE :  4.114, || R2 :  0.578

# %% [markdown]
# #The end of program
