# %% [markdown]
# <a href="https://colab.research.google.com/github/hwankang/Deep-Chemometrics/blob/master/20(sat)_11_7_08_pm__bad_test_sample_higher_NIR_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
filename_a='/content/drive/MyDrive/machine_learning/A_NIR_DATA_csv.csv'
X2_df = pd.read_csv(filename_a,header=0, 
                   encoding="unicode-escape")
X2_df
# Out:
# Mounted at /content/drive
#       Unnamed: 0  ¸ðµ¨ Æ÷ÇÔ    Y_A  899.9280058  900.2520706  900.5763689  \
# 0              1       True  24.00     0.098681     0.100515     0.102056
# 1              2       True  24.00     0.098081     0.099926     0.101394
# 2              3       True  24.00     0.089885     0.092072     0.094055
# 3              4       True  23.60     0.088701     0.090287     0.091825
# 4              5       True  23.60     0.095273     0.096945     0.098684
# ...          ...        ...    ...          ...          ...          ...
# 2034        2035       True  25.52     0.076506     0.075591     0.074629
# 2035        2036       True  25.52     0.071916     0.071201     0.070450
# 2036        2037       True  25.37     0.055557     0.054680     0.053789
# 2037        2038       True  25.37     0.050590     0.049846     0.049057
# 2038        2039       True  25.37     0.063837     0.062890     0.062142
#
#       900.9009009  901.2256669  901.5506671  901.8759019  ...  2477.700694  \
# 0        0.100267     0.096954     0.096161     0.097151  ...     2.968741
# 1        0.099664     0.096598     0.095915     0.096567  ...     2.960005
# 2        0.092618     0.089560     0.088900     0.089790  ...     2.943931
# 3        0.090534     0.087883     0.087348     0.088151  ...     2.935452
# 4        0.097460     0.094674     0.093949     0.094563  ...     2.966199
# ...           ...          ...          ...          ...  ...          ...
# 2034     0.072980     0.072275     0.072979     0.072688  ...     2.962918
# 2035     0.068871     0.068104     0.068746     0.068455  ...     2.982798
# 2036     0.052091     0.051338     0.052176     0.052068  ...     2.960384
# 2037     0.047327     0.046489     0.047292     0.047258  ...     2.968252
# 2038     0.060671     0.060073     0.060987     0.060884  ...     2.981493
#
#       2480.15873  2482.621648  2485.089463  2487.562189  2490.039841  \
# 0       2.968988     2.958685     2.950201     2.950122     2.948725
# 1       2.959948     2.951504     2.945633     2.947553     2.947326
# 2       2.943679     2.930295     2.919846     2.920668     2.922776
# 3       2.938259     2.928736     2.921757     2.924166     2.924666
# 4       2.968021     2.955198     2.942411     2.943006     2.942151
# ...          ...          ...          ...          ...          ...
# 2034    2.970997     2.967865     2.957785     2.952054     2.949278
# 2035    2.982529     2.968697     2.958179     2.962882     2.967330
# 2036    2.958313     2.946722     2.938467     2.936874     2.936340
# 2037    2.967836     2.953877     2.942397     2.945923     2.948910
# 2038    2.981399     2.970350     2.962294     2.963960     2.962348
#
#       2492.522433  2495.00998  2497.502498      2500
# 0        2.939113    2.929406     2.929555  2.927579
# 1        2.937901    2.926926     2.924102  2.920722
# 2        2.913596    2.904503     2.903535  2.901086
# 3        2.914831    2.905151     2.902643  2.897351
# 4        2.931640    2.918549     2.918717  2.917849
# ...           ...         ...          ...       ...
# 2034     2.941087    2.935639     2.936698  2.938116
# 2035     2.958188    2.948901     2.948394  2.943151
# 2036     2.925951    2.920350     2.921682  2.917657
# 2037     2.940729    2.926084     2.923839  2.919868
# 2038     2.953168    2.948091     2.949026  2.943110
#
# [2039 rows x 1782 columns]

# %%
X3_df=X2_df.iloc[:,3:]
X3_df
# Out:
#       899.9280058  900.2520706  900.5763689  900.9009009  901.2256669  \
# 0        0.098681     0.100515     0.102056     0.100267     0.096954
# 1        0.098081     0.099926     0.101394     0.099664     0.096598
# 2        0.089885     0.092072     0.094055     0.092618     0.089560
# 3        0.088701     0.090287     0.091825     0.090534     0.087883
# 4        0.095273     0.096945     0.098684     0.097460     0.094674
# ...           ...          ...          ...          ...          ...
# 2034     0.076506     0.075591     0.074629     0.072980     0.072275
# 2035     0.071916     0.071201     0.070450     0.068871     0.068104
# 2036     0.055557     0.054680     0.053789     0.052091     0.051338
# 2037     0.050590     0.049846     0.049057     0.047327     0.046489
# 2038     0.063837     0.062890     0.062142     0.060671     0.060073
#
#       901.5506671  901.8759019  902.2013713  902.5270758  902.8530155  ...  \
# 0        0.096161     0.097151     0.096790     0.095622     0.095521  ...
# 1        0.095915     0.096567     0.095609     0.094073     0.093994  ...
# 2        0.088900     0.089790     0.089088     0.087585     0.087353  ...
# 3        0.087348     0.088151     0.087593     0.086458     0.086425  ...
# 4        0.093949     0.094563     0.093743     0.092318     0.092116  ...
# ...           ...          ...          ...          ...          ...  ...
# 2034     0.072979     0.072688     0.070171     0.068566     0.069321  ...
# 2035     0.068746     0.068455     0.065891     0.064076     0.064532  ...
# 2036     0.052176     0.052068     0.049510     0.047720     0.048518  ...
# 2037     0.047292     0.047258     0.044905     0.043365     0.044220  ...
# 2038     0.060987     0.060884     0.058203     0.056162     0.056647  ...
#
#       2477.700694  2480.15873  2482.621648  2485.089463  2487.562189  \
# 0        2.968741    2.968988     2.958685     2.950201     2.950122
# 1        2.960005    2.959948     2.951504     2.945633     2.947553
# 2        2.943931    2.943679     2.930295     2.919846     2.920668
# 3        2.935452    2.938259     2.928736     2.921757     2.924166
# 4        2.966199    2.968021     2.955198     2.942411     2.943006
# ...           ...         ...          ...          ...          ...
# 2034     2.962918    2.970997     2.967865     2.957785     2.952054
# 2035     2.982798    2.982529     2.968697     2.958179     2.962882
# 2036     2.960384    2.958313     2.946722     2.938467     2.936874
# 2037     2.968252    2.967836     2.953877     2.942397     2.945923
# 2038     2.981493    2.981399     2.970350     2.962294     2.963960
#
#       2490.039841  2492.522433  2495.00998  2497.502498      2500
# 0        2.948725     2.939113    2.929406     2.929555  2.927579
# 1        2.947326     2.937901    2.926926     2.924102  2.920722
# 2        2.922776     2.913596    2.904503     2.903535  2.901086
# 3        2.924666     2.914831    2.905151     2.902643  2.897351
# 4        2.942151     2.931640    2.918549     2.918717  2.917849
# ...           ...          ...         ...          ...       ...
# 2034     2.949278     2.941087    2.935639     2.936698  2.938116
# 2035     2.967330     2.958188    2.948901     2.948394  2.943151
# 2036     2.936340     2.925951    2.920350     2.921682  2.917657
# 2037     2.948910     2.940729    2.926084     2.923839  2.919868
# 2038     2.962348     2.953168    2.948091     2.949026  2.943110
#
# [2039 rows x 1779 columns]

# %%
#special run
#X_df_1=X3_df.iloc[39:,:]
#X_df_2=X3_df.iloc[18:39,:]
#X_df_3=X3_df.iloc[0:18,:]
X_df_1=X3_df.iloc[170:,:]
X_df_2=X3_df.iloc[70:170,:]
X_df_3=X3_df.iloc[0:70,:]
X_train_df=X_df_1
X_val_df=X_df_2
X_test_df=X_df_3

# %%
Y3_df=X2_df.iloc[:,2:3]
Y3_df
# Out:
#         Y_A
# 0     24.00
# 1     24.00
# 2     24.00
# 3     23.60
# 4     23.60
# ...     ...
# 2034  25.52
# 2035  25.52
# 2036  25.37
# 2037  25.37
# 2038  25.37
#
# [2039 rows x 1 columns]

# %%
#Y_df_1=Y3_df.iloc[39:,:]
#Y_df_2=Y3_df.iloc[18:39,:]
#Y_df_3=Y3_df.iloc[0:18,:]
Y_df_1=Y3_df.iloc[170:,:]
Y_df_2=Y3_df.iloc[70:170,:]
Y_df_3=Y3_df.iloc[0:70,:]
y_train_df=Y_df_1
y_val_df=Y_df_2
y_test_df=Y_df_3

# %%
X_train_val_df=X_train_df.append(X_val_df)
X_train_val=X_train_val_df.values
X_train_a=X_train_df.values
X_val_a=X_val_df.values
X_test_a=X_test_df.values
y_train=y_train_df.values
y_val=y_val_df.values
y_test=y_test_df.values

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
#X_train_val=X_train_a.append(X_val_a)
#std.fit(X_train_val)
std.fit(X_train_a)
X_train=std.transform(X_train_a)
#std.fit(X_val_a)
X_val=std.transform(X_val_a)
#std.fit(X_test_a)
X_test=std.transform(X_test_a)

# %%
dn=X3_df.keys().to_numpy()
dn
axisscale=dn.astype('float')
axisscale
#array(['899.9280058', '900.2520706', '900.5763689', ..., '2495.00998',
#       '2497.502498', '2500'], dtype=object)
# Out:
# array([ 899.9280058,  900.2520706,  900.5763689, ..., 2495.00998  ,
#        2497.502498 , 2500.       ])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(axisscale,X_train.T)
plt.xlabel('nm')
plt.ylabel('normalized intensity')
plt.title('Normalized training data')
plt.show()

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv1D, Reshape#, MaxPooling1D
from keras.callbacks import ReduceLROnPlateau
from keras.layers.noise import GaussianNoise

# %%
#Hyperparameters for the network
DENSE = 128
#DROPOUT = 0.025
DROPOUT = 0
C1_K  = 8 #Number of kernels/feature extractors for first layer
C1_S  = 32 #Width of the convolutional mini networks
C2_K  = 16
C2_S  = 32

activation='relu'
#activation='sigmoid'

input_dim = X_train.shape[1]

#The model
def make_model():
    model = Sequential()
    #Adding a bit of GaussianNoise also works as regularization
    #model.add(GaussianNoise(0.05, input_shape=(input_dim,)))
    #model.add(GaussianNoise(0.005, input_shape=(input_dim,)))
    model.add(GaussianNoise(0.003, input_shape=(input_dim,)))
    #First two is number of filter + kernel size
    model.add(Reshape((input_dim, 1)))
    #model.add(Conv1D(C1_K, (C1_S), activation=activation, border_mode='same'))
    #model.add(Conv1D(C2_K, (C2_S), border_mode='same', activation=activation))
    model.add(Conv1D(C1_K, (C1_S), activation=activation, padding='same'))
    model.add(Conv1D(C2_K, (C2_S), padding='same', activation=activation))
    model.add(Flatten())
    model.add(Dropout(DROPOUT))
    model.add(Dense(DENSE, activation=activation))
    model.add(Dense(1, activation='linear'))

    #model.compile(loss='mse', optimizer=keras.optimizers.Adadelta(lr=0.01))#, metrics=['mean_absolute_error'])
    model.compile(loss='mse', optimizer=keras.optimizers.Adam(lr=0.005))#, metrics=['mean_absolute_error'])

    return model

# %%
model = make_model()
print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gaussian_noise_5 (GaussianN  (None, 1779)             0
#  oise)
#
#  reshape_5 (Reshape)         (None, 1779, 1)           0
#
#  conv1d_10 (Conv1D)          (None, 1779, 8)           264
#
#  conv1d_11 (Conv1D)          (None, 1779, 16)          4112
#
#  flatten_5 (Flatten)         (None, 28464)             0
#
#  dropout_5 (Dropout)         (None, 28464)             0
#
#  dense_10 (Dense)            (None, 128)               3643520
#
#  dense_11 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 3,648,025
# Trainable params: 3,648,025
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
h = model.fit(X_train, y_train, epochs=100, batch_size=8, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 234/234 [==============================] - 17s 71ms/step - loss: 480.7011 - val_loss: 376.1933
# Epoch 2/100
# 234/234 [==============================] - 16s 68ms/step - loss: 221.5186 - val_loss: 154.4737
# Epoch 3/100
# 234/234 [==============================] - 15s 64ms/step - loss: 66.0752 - val_loss: 76.5330
# Epoch 4/100
# 234/234 [==============================] - 15s 63ms/step - loss: 27.4479 - val_loss: 67.3770
# Epoch 5/100
# 234/234 [==============================] - 16s 69ms/step - loss: 24.1121 - val_loss: 67.3108
# Epoch 6/100
# 234/234 [==============================] - 15s 65ms/step - loss: 24.0502 - val_loss: 67.2932
# Epoch 7/100
# 234/234 [==============================] - 16s 67ms/step - loss: 24.0389 - val_loss: 67.4384
# Epoch 8/100
# 234/234 [==============================] - 16s 66ms/step - loss: 24.0775 - val_loss: 67.3165
# Epoch 9/100
# 234/234 [==============================] - 17s 72ms/step - loss: 24.0524 - val_loss: 67.2778
# Epoch 10/100
# 234/234 [==============================] - 16s 67ms/step - loss: 24.0725 - val_loss: 67.3362
# Epoch 11/100
# 234/234 [==============================] - 15s 66ms/step - loss: 24.0477 - val_loss: 67.2826
# Epoch 12/100
# 234/234 [==============================] - 15s 66ms/step - loss: 24.0690 - val_loss: 67.2675
# Epoch 13/100
# 234/234 [==============================] - 16s 68ms/step - loss: 24.0797 - val_loss: 67.2597
# Epoch 14/100
# 234/234 [==============================] - 16s 68ms/step - loss: 24.0449 - val_loss: 67.4184
# Epoch 15/100
# 234/234 [==============================] - 14s 62ms/step - loss: 24.0594 - val_loss: 67.5339
# Epoch 16/100
# 234/234 [==============================] - 15s 64ms/step - loss: 24.0623 - val_loss: 68.4486
# Epoch 17/100
# 234/234 [==============================] - 16s 67ms/step - loss: 24.0791 - val_loss: 67.3431
# Epoch 18/100
# 234/234 [==============================] - 16s 67ms/step - loss: 23.9952 - val_loss: 67.4856
# Epoch 19/100
# 234/234 [==============================] - 17s 74ms/step - loss: 23.9428 - val_loss: 67.4322
# Epoch 20/100
# 234/234 [==============================] - 15s 66ms/step - loss: 23.9873 - val_loss: 67.7097
# Epoch 21/100
# 234/234 [==============================] - 16s 69ms/step - loss: 24.0622 - val_loss: 67.3504
# Epoch 22/100
# 234/234 [==============================] - 15s 63ms/step - loss: 24.0396 - val_loss: 67.3202
# Epoch 23/100
# 234/234 [==============================] - 15s 63ms/step - loss: 24.0803 - val_loss: 67.3202
# Epoch 24/100
# 234/234 [==============================] - 15s 66ms/step - loss: 24.0835 - val_loss: 67.3593
# Epoch 25/100
# 234/234 [==============================] - 16s 68ms/step - loss: 24.0874 - val_loss: 67.2913
# Epoch 26/100
# 234/234 [==============================] - 15s 63ms/step - loss: 24.0148 - val_loss: 67.7341
# Epoch 27/100
# 234/234 [==============================] - 15s 63ms/step - loss: 23.9573 - val_loss: 68.1870
# Epoch 28/100
# 234/234 [==============================] - 15s 66ms/step - loss: 23.9848 - val_loss: 67.5193
# Epoch 29/100
# 234/234 [==============================] - 15s 64ms/step - loss: 24.0031 - val_loss: 67.3778
# Epoch 30/100
# 234/234 [==============================] - 17s 72ms/step - loss: 23.9380 - val_loss: 67.2854
# Epoch 31/100
# 234/234 [==============================] - 15s 66ms/step - loss: 24.0628 - val_loss: 68.8120
# Epoch 32/100
# 234/234 [==============================] - 16s 67ms/step - loss: 24.1273 - val_loss: 67.3400
# Epoch 33/100
# 234/234 [==============================] - 16s 68ms/step - loss: 23.9425 - val_loss: 67.6366
# Epoch 34/100
# 234/234 [==============================] - 16s 67ms/step - loss: 24.0828 - val_loss: 67.2468
# Epoch 35/100
# 234/234 [==============================] - 16s 68ms/step - loss: 24.0156 - val_loss: 67.3025
# Epoch 36/100
# 234/234 [==============================] - 15s 66ms/step - loss: 24.0296 - val_loss: 67.2722
# Epoch 37/100
# 234/234 [==============================] - 15s 66ms/step - loss: 23.9998 - val_loss: 67.5392
# Epoch 38/100
# 234/234 [==============================] - 15s 66ms/step - loss: 24.0281 - val_loss: 67.3069
# Epoch 39/100
# 234/234 [==============================] - 15s 65ms/step - loss: 23.9709 - val_loss: 67.4756
# Epoch 40/100
# 234/234 [==============================] - 15s 66ms/step - loss: 24.0502 - val_loss: 67.3177
# Epoch 41/100
# 234/234 [==============================] - 17s 73ms/step - loss: 24.0427 - val_loss: 67.3656
# Epoch 42/100
# 234/234 [==============================] - 15s 66ms/step - loss: 24.0127 - val_loss: 67.4391
# Epoch 43/100
# 234/234 [==============================] - 16s 67ms/step - loss: 23.9174 - val_loss: 67.8778
# Epoch 44/100
# 234/234 [==============================] - 16s 67ms/step - loss: 23.9943 - val_loss: 67.2550
# Epoch 45/100
# 234/234 [==============================] - 14s 60ms/step - loss: 23.8837 - val_loss: 67.2277
# Epoch 46/100
# 234/234 [==============================] - 14s 61ms/step - loss: 23.5937 - val_loss: 67.3818
# Epoch 47/100
# 234/234 [==============================] - 14s 61ms/step - loss: 23.3624 - val_loss: 66.6728
# Epoch 48/100
# 234/234 [==============================] - 14s 61ms/step - loss: 23.1338 - val_loss: 66.4710
# Epoch 49/100
# 234/234 [==============================] - 14s 61ms/step - loss: 23.0879 - val_loss: 66.8995
# Epoch 50/100
# 234/234 [==============================] - 14s 61ms/step - loss: 22.3448 - val_loss: 67.4067
# Epoch 51/100
# 234/234 [==============================] - 14s 61ms/step - loss: 22.0182 - val_loss: 66.8275
# Epoch 52/100
# 234/234 [==============================] - 14s 62ms/step - loss: 21.8359 - val_loss: 66.7460
# Epoch 53/100
# 234/234 [==============================] - 16s 69ms/step - loss: 20.9989 - val_loss: 66.9001
# Epoch 54/100
# 234/234 [==============================] - 14s 61ms/step - loss: 20.9601 - val_loss: 65.8705
# Epoch 55/100
# 234/234 [==============================] - 14s 61ms/step - loss: 20.0810 - val_loss: 68.4072
# Epoch 56/100
# 234/234 [==============================] - 14s 61ms/step - loss: 19.7880 - val_loss: 73.9287
# Epoch 57/100
# 234/234 [==============================] - 14s 61ms/step - loss: 19.5145 - val_loss: 69.8539
# Epoch 58/100
# 234/234 [==============================] - 14s 61ms/step - loss: 19.6245 - val_loss: 71.1524
# Epoch 59/100
# 234/234 [==============================] - 14s 61ms/step - loss: 19.0765 - val_loss: 66.2189
# Epoch 60/100
# 234/234 [==============================] - 14s 61ms/step - loss: 18.3094 - val_loss: 68.1862
# Epoch 61/100
# 234/234 [==============================] - 14s 61ms/step - loss: 18.4880 - val_loss: 66.9396
# Epoch 62/100
# 234/234 [==============================] - 14s 61ms/step - loss: 17.6365 - val_loss: 65.6100
# Epoch 63/100
# 234/234 [==============================] - 14s 61ms/step - loss: 16.9022 - val_loss: 70.8328
# Epoch 64/100
# 234/234 [==============================] - 16s 68ms/step - loss: 17.3269 - val_loss: 70.2586
# Epoch 65/100
# 234/234 [==============================] - 14s 61ms/step - loss: 17.0636 - val_loss: 73.0425
# Epoch 66/100
# 234/234 [==============================] - 14s 61ms/step - loss: 16.6811 - val_loss: 72.9881
# Epoch 67/100
# 234/234 [==============================] - 14s 61ms/step - loss: 16.3861 - val_loss: 72.3539
# Epoch 68/100
# 234/234 [==============================] - 14s 61ms/step - loss: 15.9511 - val_loss: 74.2780
# Epoch 69/100
# 234/234 [==============================] - 14s 61ms/step - loss: 15.6110 - val_loss: 75.6222
# Epoch 70/100
# 234/234 [==============================] - 14s 61ms/step - loss: 16.7621 - val_loss: 67.1242
# Epoch 71/100
# 234/234 [==============================] - 14s 61ms/step - loss: 16.6909 - val_loss: 71.8098
# Epoch 72/100
# 234/234 [==============================] - 14s 61ms/step - loss: 14.9018 - val_loss: 69.3568
# Epoch 73/100
# 234/234 [==============================] - 14s 61ms/step - loss: 14.9373 - val_loss: 71.9442
# Epoch 74/100
# 234/234 [==============================] - 14s 61ms/step - loss: 14.9320 - val_loss: 74.0440
# Epoch 75/100
# 234/234 [==============================] - 14s 61ms/step - loss: 15.5287 - val_loss: 69.9662
# Epoch 76/100
# 234/234 [==============================] - 16s 69ms/step - loss: 14.3180 - val_loss: 68.3992
# Epoch 77/100
# 234/234 [==============================] - 14s 61ms/step - loss: 13.9042 - val_loss: 66.9536
# Epoch 78/100
# 234/234 [==============================] - 14s 61ms/step - loss: 14.0404 - val_loss: 72.6124
# Epoch 79/100
# 234/234 [==============================] - 14s 61ms/step - loss: 13.7734 - val_loss: 67.7176
# Epoch 80/100
# 234/234 [==============================] - 14s 62ms/step - loss: 13.3063 - val_loss: 67.0300
# Epoch 81/100
# 234/234 [==============================] - 14s 61ms/step - loss: 12.4201 - val_loss: 70.7154
# Epoch 82/100
# 234/234 [==============================] - 14s 61ms/step - loss: 12.0431 - val_loss: 68.5093
# Epoch 83/100
# 234/234 [==============================] - 14s 61ms/step - loss: 12.6081 - val_loss: 69.0057
# Epoch 84/100
# 234/234 [==============================] - 14s 61ms/step - loss: 11.2704 - val_loss: 72.7190
# Epoch 85/100
# 234/234 [==============================] - 14s 61ms/step - loss: 11.5089 - val_loss: 68.1611
# Epoch 86/100
# 234/234 [==============================] - 14s 61ms/step - loss: 11.1096 - val_loss: 67.6297
# Epoch 87/100
# 234/234 [==============================] - 14s 61ms/step - loss: 10.7279 - val_loss: 71.4741
# Epoch 88/100
# 234/234 [==============================] - 16s 69ms/step - loss: 11.2543 - val_loss: 66.8949
# Epoch 89/100
# 234/234 [==============================] - 14s 61ms/step - loss: 11.2934 - val_loss: 78.8869
# Epoch 90/100
# 234/234 [==============================] - 15s 63ms/step - loss: 11.1698 - val_loss: 73.8673
# Epoch 91/100
# 234/234 [==============================] - 14s 62ms/step - loss: 11.7222 - val_loss: 73.4757
# Epoch 92/100
# 234/234 [==============================] - 15s 62ms/step - loss: 10.5217 - val_loss: 69.4324
# Epoch 93/100
# 234/234 [==============================] - 14s 61ms/step - loss: 10.0193 - val_loss: 73.9327
# Epoch 94/100
# 234/234 [==============================] - 14s 61ms/step - loss: 10.2024 - val_loss: 75.3466
# Epoch 95/100
# 234/234 [==============================] - 14s 61ms/step - loss: 9.4631 - val_loss: 71.7883
# Epoch 96/100
# 234/234 [==============================] - 14s 61ms/step - loss: 9.6559 - val_loss: 75.2986
# Epoch 97/100
# 234/234 [==============================] - 14s 61ms/step - loss: 9.2741 - val_loss: 70.5723
# Epoch 98/100
# 234/234 [==============================] - 14s 61ms/step - loss: 8.9266 - val_loss: 68.4773
# Epoch 99/100
# 234/234 [==============================] - 14s 61ms/step - loss: 9.5253 - val_loss: 76.1435
# Epoch 100/100
# 234/234 [==============================] - 16s 69ms/step - loss: 10.7009 - val_loss: 75.3194

# %%
#import matplotlib.psplot as plt
import matplotlib.pyplot as plt
plt.plot(h.history['loss'], label='loss')
plt.plot(h.history['val_loss'], label='val_loss')

plt.yscale('log')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
ax2 = plt.gca().twinx()
ax2.plot(h.history['lr'], color='r')
ax2.set_ylabel('lr',color='r')

_ = plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-f0efbcbef879> in <module>
#       9 plt.legend()
#      10 ax2 = plt.gca().twinx()
# ---> 11 ax2.plot(h.history['lr'], color='r')
#      12 ax2.set_ylabel('lr',color='r')
#      13
#
# KeyError: 'lr'

# %%
plt.scatter(y_train, model.predict(X_train))
plt.scatter(y_val, model.predict(X_val))
plt.scatter(y_test, model.predict(X_test))
plt.plot([0,30],[0,30]) # Y = PredY line
plt.xlabel('true value')
plt.ylabel('predicted value')
# Out:
# 59/59 [==============================] - 2s 27ms/step
# 4/4 [==============================] - 0s 21ms/step
# 3/3 [==============================] - 0s 18ms/step
# Text(0, 0.5, 'predicted value')

# %%
pred_Y_df=model.predict(X_test)
Y_df_true=y_test
from sklearn.metrics import mean_squared_error, r2_score
mse= mean_squared_error(Y_df_true, pred_Y_df)
rmse=np.sqrt(mse)
r2=r2_score(Y_df_true, pred_Y_df)
print('MSE : {: 0.3f}, || RMSE : {: 0.3f}, || R2 : {: 0.3f}'.format(mse,rmse,r2))
# Out:
# 3/3 [==============================] - 0s 25ms/step
# MSE :  11.839, || RMSE :  3.441, || R2 : -7.975
